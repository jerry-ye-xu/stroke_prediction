# %% [markdown]
# ## Summary
#
# We need to handle the test dataset in the same way as we handled the training dataset.
#
# So first we wrangle.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

from wrangle_helper import split_row, split_tup, swap_job_living, swap_sex_age

# %matplotlib inline

# %%
stk = pd.read_csv("../data/test.csv")
stk.head()
# Out:
#       id sex and age  high_BP  heart_condition_detected_2017  married  \
# 0  33327       F, 36      0.0                            0.0      1.0
# 1    839       F, 40      0.0                            0.0      1.0
# 2  11127       M, 59      0.0                            0.0      1.0
# 3  20768       33, F      0.0                            0.0      1.0
# 4  37774       F, 22      0.0                            0.0      0.0
#
#   job_status and living_area  average_blood_sugar   BMI  smoker_status  \
# 0      private_sector?Remote                76.05  33.4  active_smoker
# 1            City?government                73.77  30.1     non-smoker
# 2      business_owner?Remote                62.95  30.8            NaN
# 3        private_sector?City                68.81  36.5           quit
# 4        private_sector?City               122.89  30.8  active_smoker
#
#    TreatmentA  TreatmentB  TreatmentC  TreatmentD
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
stk.shape
# Out:
# (8718, 13)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Highly Imbalanced Dataset!
# </div>

# %%
stk.columns
# Out:
# Index(['id', 'sex and age', 'high_BP', 'heart_condition_detected_2017',
#        'married', 'job_status and living_area', 'average_blood_sugar', 'BMI',
#        'smoker_status', 'TreatmentA', 'TreatmentB', 'TreatmentC',
#        'TreatmentD'],
#       dtype='object')

# %%
stk.shape
# Out:
# (8718, 13)

# %%
stk["job_status and living_area"].unique()
# Out:
# array(['private_sector?Remote', 'City?government',
#        'business_owner?Remote', 'private_sector?City',
#        'business_owner?City', 'government?City', 'City?private_sector',
#        'parental_leave?Remote', 'government?Remote',
#        'Remote?private_sector', 'parental_leave?City',
#        'City?parental_leave', 'Remote?parental_leave',
#        'Remote?business_owner', 'unemployed?Remote',
#        'City?business_owner', 'Remote?government', 'goVT.?Remote',
#        '?City', 'remote?private_sector', 'GOVERNMENT?Remote',
#        'parental_leave?remote', 'City?unemployed',
#        'private_sector?remote', 'private_sector???', 'unemployed?City',
#        nan, 'govt.?Remote', 'BUSINESS OWNER?City', 'private sector?City',
#        'biz?City', 'city?private_sector', 'private_sector?CITY',
#        'Private?Remote', 'r?private_sector', 'c?business_owner',
#        'governMENT?City', 'City?GOVT.', 'Remote?unemployed',
#        'business owner?Remote'], dtype=object)

# %%
stk["sex and age"].unique()
# Out:
# array(['F, 36', 'F, 40', 'M, 59', '33, F', 'F, 22', 'M, 60', 'F, 83',
#        'M, 47', 'F, 82', 'F, 49', 'M, 58', 'M, 82', 'M, 4.88', 'F, 38',
#        'M, 50', 'F, 84', 'F, 68', 'M, 40', 'M, 52', 'M, 62', 'M, 35',
#        '32, F', 'M, 14', 'F, 35', 'F, 43', 'M, 43', 'M, 12', 'F, 55',
#        'F, 33', 'F, 30', '36, M', 'F, 56', 'F, 78', 'M, 69', 'M, 48',
#        'F, 64', 'F, 16', 'F, 63', 'F, 58', 'M, 26', 'F, 29', 'F, 61',
#        'M, 79', 'M, 20', 'F, 5', 'F, 42', 'F, 72', 'F, 48', 'M, 73',
#        'M, 21', 'M, 55', 'M, 34', 'F, 27', 'F, 41', 'F, 52', 'M, 31',
#        'F, 47', 'F, 18', 'M, 85', 'M, 78', 'M, 3.72', 'M, 51', '50, M',
#        'F, 4.08', 'F, 71', '63, F', 'F, 76', 'M, 45', 'M, 67', 'F, 60',
#        'M, 19', 'F, 45', 'M, 17', 'F, 46', 'M, 7', 'F, 62', 'M, 65',
#        'F, 66', 'F, 81', 'F, 50', '65, F', 'M, 54', 'F, 39', 'F, 3.32',
#        'M, 6', 'F, 53', 'F, 28', 'F, 37', 'F, 57', 'F, 24', 'F, 65',
#        'F, 26', 'F, 20', 'M, 8', 'F, 32', 'F, 80', '51, F', 'F, 4',
#        'F, 59', 'F, 51', 'M, 13', 'F, 44', '35, M', 'F, 14', '4.72, F',
#        'F, 69', 'M, 64', 'M, 28', 'F, 34', '67, F', 'M, 25', '80, F',
#        'F, 3.88', 'M, 44', 'F, 74', 'F, 31', 'M, 71', '60, M', 'M, 76',
#        'M, 33', 'M, 68', 'M, 80', '57, F', 'M, 37', 'F, 21', 'M, 46',
#        'M, 49', '77, F', 'M, 74', 'F, 4.64', 'F, 67', '20, F', 'F, 15',
#        '37, F', 'M, 81', 'F, 17', '59, M', 'F, 13', 'M, 56', '34, M',
#        '9, F', 'F, 85', 'M, 18', 'F, 4.24', '16, F', 'M, 32', '72, F',
#        'F, 23', 'F, 7', 'M, 63', 'M, 5', 'M, 84', 'F, 70', 'F, 54',
#        'F, 25', 'M, 57', 'm, 53', 'M, 3.32', 'M, 42', 'M, 11', '26, F',
#        'F, 77', 'F, 12', 'F, 73', 'M, 39', 'M, 22', '30, F', '41, M',
#        'M, 3.56', 'F, 75', 'M, 38', '85, M', 'M, 4', 'M, 4.32', 'M, 61',
#        '11, F', 'M, 36', 'M, 3.48', 'M, 66', '78, M', 'F, 11', 'M, 15',
#        'M, 4.08', 'Other, 14', '12, F', 'F, 19', '47, F', 'F, 79',
#        '56, F', 'M, 75', 'M, 53', 'F, 3.64', '4.4, F', '55, F', '39, M',
#        'Other, 30', '83, F', 'M, 24', 'M, 29', 'M, 70', 'F, 8', '42, M',
#        'M, 16', '52, M', '41, F', '52, F', 'M, 27', '27, M', '57, M',
#        '40, F', '58, F', 'M, 41', '66, M', '31, F', '83, M', 'F, 6',
#        '56, M', '68, F', '65, M', '5, F', '59, F', '43, F', 'F, 3.72',
#        'M, 4.16', '3.56, F', '44, F', '15, M', 'M, 10', '6, M', 'F, 4.72',
#        'M, 83', '14, M', '42, F', '82, F', '23, M', 'Other, 54', 'M, 30',
#        '30, M', 'F, 4.32', '32, M', 'M, 3.8', 'M, 3.64', '23, F', 'F, 10',
#        'F, 3.56', '62, F', '69, F', 'F, 4.48', '73, F', '22, F', '19, F',
#        '6, F', '54, F', '81, F', 'M, 4.4', '27, F', '85, F', '36, F',
#        'M, 77', '64, M', '71, F', '78, F', '40, M', 'F, 9', '13, M',
#        'M, 3.08', '45, F', '4.56, M', '46, F', '75, F', 'M, 4.56',
#        '17, F', '61, F', '7, F', '10, F', 'M, 23', '25, F', 'M, 9',
#        'F, 3.16', nan, 'F, 3.08', '55, M', '64, F', '44, M', 'M, 4.8',
#        '46, M', 'F, 4.56', '58, M', 'M, 72', '24, F', '38, F', '7, M',
#        'M, 3.24', '3.64, M', 'F, 4.4', '53, M', '21, F', '51, M', '17, M',
#        '5, M', '26, M', '66, F', '9, M', '33, M', '24, M', 'M, 4.72',
#        'M, 3.4', '71, M', 'M, 3.88', 'f, 33', '39, F', '19, M', '35, F',
#        '67, M', '62, M', '50, F', '3.72, M', 'F, 3.24', 'F, 4.16',
#        '74, F', '47, M', '49, F', 'M, 4.48', 'M, fifteen', '21, M',
#        '10, M', 'F, 4.88', '3.88, M', '45, M', '79, F', '14, F', '54, M',
#        '28, F', '31, M', '68, M', 'M, sixty-seven', '48, M', 'F, 4.8',
#        'M, 4.24', '20, M', '49, M', '53, F', '34, F', 'F, 3.8', '70, F',
#        '15, F', 'Other, 29', '61, M', 'M, 4.64', '84, F', '25, M',
#        'F, eight', '84, M', '48, F', '3.8, M', 'F, 3.48', '60, F',
#        '12, M', 'M, 3.16', '8, F', '43, M', '29, F', '81, M', 'F, fifty',
#        'FEMALE, 34', 'MALE, 43', '76, M', 'F, 3.4', '82, M', '80, M',
#        '69, M', '37, M', '3.8, F', '74, M', '76, F', '77, M', '63, M',
#        '4.24, M', 'MALE, 76', '72, M', '70, M', '3.64, F', '18, F',
#        '73, M', '3.08, F', '75, M', '4, M', '38, M', '8, M',
#        'F, sixty-seven', 'F, sixty three', '4.48, M', '22, M',
#        'M, twenty two'], dtype=object)

# %% [markdown]
# Looks like there are some variables that need to be wrangled.

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# ## Wrangling Begins Here

# %% [markdown]
# <div class="alert alert-block alert-info">
# Check Job status and living area
# </div>

# %%
stk["job_status_living_area"] = stk["job_status and living_area"].apply(split_row, args="?")
stk["job_status_living_area"].head()
# Out:
# 0    (private_sector, Remote)
# 1          (City, government)
# 2    (business_owner, Remote)
# 3      (private_sector, City)
# 4      (private_sector, City)
# Name: job_status_living_area, dtype: object

# %%
stk['job_status'], stk['living_area'] = zip(*stk['job_status_living_area'].map(split_tup))
stk[["job_status_living_area", "job_status", "living_area"]].head()
# Out:
#      job_status_living_area      job_status living_area
# 0  (private_sector, Remote)  private_sector      Remote
# 1        (City, government)            City  government
# 2  (business_owner, Remote)  business_owner      Remote
# 3    (private_sector, City)  private_sector        City
# 4    (private_sector, City)  private_sector        City

# %% [markdown]
# ---
# __Living Area__
# ---

# %% [markdown]
# Make everything lowercase, remove weird variables, and correct spelling

# %%
stk["living_area"] = stk["living_area"].apply(lambda x: x.lower())

# %%
print(stk["living_area"].value_counts())
print(stk["living_area"].unique())
# Out:
# city              3756
# remote            3738
# private_sector     719
# business_owner     179
# parental_leave     170
# government         138
# a                   10
# unemployed           6
# govt.                1
#                      1
# Name: living_area, dtype: int64
# ['remote' 'government' 'city' 'private_sector' 'parental_leave'
#  'business_owner' 'unemployed' '' 'a' 'govt.']

# %%
stk.loc[stk["living_area"] == "privattte", "living_area"] = "private_sector"
print(stk["living_area"].value_counts())
# Out:
# city              3756
# remote            3738
# private_sector     719
# business_owner     179
# parental_leave     170
# government         138
# a                   10
# unemployed           6
# govt.                1
#                      1
# Name: living_area, dtype: int64

# %%
stk[stk["living_area"] == "government"]
# Out:
#          id sex and age  high_BP  heart_condition_detected_2017  married  \
# 1       839       F, 40      0.0                            0.0      1.0
# 20     2813       M, 62      0.0                            0.0      1.0
# 122   24579       M, 52      0.0                            0.0      0.0
# 159   24924       F, 78      1.0                            0.0      1.0
# 172     625       M, 44      0.0                            0.0      NaN
# 208    2247       F, 45      0.0                            0.0      1.0
# 222    2181       F, 72      1.0                            0.0      1.0
# 288    2874       M, 63      1.0                            0.0      1.0
# 315    3030       F, 27      0.0                            0.0      0.0
# 520   24156       M, 68      0.0                            1.0      1.0
# 548    1489       F, 55      0.0                            0.0      1.0
# 588     884       M, 70      0.0                            0.0      1.0
# 736   24984       F, 32      0.0                            0.0      1.0
# 779    1786       F, 64      1.0                            0.0      1.0
# 804   25799       F, 66      0.0                            0.0      1.0
# 857    3633       F, 63      0.0                            0.0      1.0
# 910    1331       F, 37      0.0                            0.0      1.0
# 953   25541       M, 53      0.0                            0.0      1.0
# 1029  25626       F, 58      0.0                            0.0      1.0
# 1038   3928       M, 41      0.0                            0.0      1.0
# 1051   1826       M, 25      0.0                            0.0      0.0
# 1070   2304       M, 74      0.0                            0.0      1.0
# 1093  25729       M, 64      1.0                            0.0      1.0
# 1234   3105       F, 37      0.0                            0.0      1.0
# 1346   2494       M, 55      0.0                            0.0      1.0
# 1371  26022       M, 64      0.0                            0.0      1.0
# 1408    898       F, 39      0.0                            0.0      1.0
# 1474  24145       F, 49      0.0                            0.0      1.0
# 1521   3396       M, 43      0.0                            0.0      0.0
# 1531    476       F, 78      0.0                            0.0      1.0
# ...     ...         ...      ...                            ...      ...
# 6786   1396       F, 27      0.0                            0.0      0.0
# 6801  25286       M, 78      0.0                            1.0      1.0
# 6833    437       F, 69      0.0                            0.0      1.0
# 6952   1576       F, 53      1.0                            0.0      1.0
# 7117   3106       F, 68      0.0                            0.0      1.0
# 7132  24679       M, 48      0.0                            0.0      1.0
# 7209   1412       F, 44      0.0                            0.0      1.0
# 7228  25937       F, 51      0.0                            0.0      1.0
# 7374   3852       F, 54      0.0                            0.0      1.0
# 7400  25776       F, 45      0.0                            0.0      1.0
# 7406  25749       M, 78      0.0                            1.0      1.0
# 7416  24096       F, 83      0.0                            1.0      1.0
# 7671   1555       F, 63      0.0                            0.0      1.0
# 7746  25284       M, 47      1.0                            0.0      1.0
# 7800   2245       M, 56      0.0                            0.0      1.0
# 7836  25576       M, 50      1.0                            0.0      1.0
# 8087   2448       M, 62      0.0                            0.0      1.0
# 8147   3401       M, 27      0.0                            0.0      0.0
# 8149  24257       F, 62      0.0                            0.0      1.0
# 8165  25798       M, 74      1.0                            1.0      1.0
# 8190  25304       M, 49      0.0                            0.0      1.0
# 8192  25858       F, 58      0.0                            0.0      1.0
# 8268    991       F, 37      0.0                            0.0      0.0
# 8304   1446       F, 69      0.0                            0.0      1.0
# 8406    927       M, 36      0.0                            0.0      1.0
# 8438   3834       M, 62      0.0                            0.0      0.0
# 8525    344       M, 32      0.0                            0.0      1.0
# 8551  25153       M, 49      1.0                            0.0      1.0
# 8579   2756       F, 47      1.0                            0.0      1.0
# 8685   3027       M, 47      0.0                            0.0      1.0
#
#      job_status and living_area  average_blood_sugar   BMI  smoker_status  \
# 1               City?government                73.77  30.1     non-smoker
# 20              City?government                74.64  33.7     non-smoker
# 122             City?government                80.10  24.8  active_smoker
# 159             City?government                97.31  28.8     non-smoker
# 172             City?government               111.58  29.9     non-smoker
# 208             City?government                61.31  27.5            NaN
# 222             City?government               116.80   NaN     non-smoker
# 288             City?government               217.63  22.5  active_smoker
# 315             City?government               109.46  22.1     non-smoker
# 520           Remote?government               203.59  31.5     non-smoker
# 548           Remote?government                73.71  37.5     non-smoker
# 588             City?government                72.39  28.3           quit
# 736           Remote?government                82.41  24.9     non-smoker
# 779             City?government               157.98  41.1     non-smoker
# 804             City?government               210.68  38.1     non-smoker
# 857           Remote?government               150.54  31.5            NaN
# 910           Remote?government                74.78  27.2            NaN
# 953             City?government               100.72  44.8     non-smoker
# 1029            City?government               101.22  36.4  active_smoker
# 1038            City?government               127.43  32.9            NaN
# 1051          Remote?government               100.78  27.4     non-smoker
# 1070            City?government                60.72    27            NaN
# 1093          Remote?government               104.82  40.4     non-smoker
# 1234          Remote?government                90.96  34.4  active_smoker
# 1346            City?government                72.10    30  active_smoker
# 1371          Remote?government               153.28    29            NaN
# 1408          Remote?government                87.07  35.4  active_smoker
# 1474          Remote?government                72.07  36.8     non-smoker
# 1521            City?government               201.71  26.2     non-smoker
# 1531          Remote?government                60.83  27.6     non-smoker
# ...                         ...                  ...   ...            ...
# 6786            City?government                68.00  22.6  active_smoker
# 6801            City?government               235.49  26.4  active_smoker
# 6833            City?government                96.64  25.4     non-smoker
# 6952            City?government                64.49  27.8     non-smoker
# 7117            City?government                87.32  32.1  active_smoker
# 7132            City?government                83.37  44.2     non-smoker
# 7209            City?government                96.53    27  active_smoker
# 7228          Remote?government                97.71    36           quit
# 7374            City?government                95.27  40.1            NaN
# 7400            City?government                83.81  28.7            NaN
# 7406            City?government               112.82  31.7           quit
# 7416          Remote?government               208.12  30.6     non-smoker
# 7671          Remote?government                66.54  30.2           quit
# 7746            City?government                79.15   NaN     non-smoker
# 7800          Remote?government                90.60  26.4     non-smoker
# 7836          Remote?government               117.96  29.9     non-smoker
# 8087          Remote?government               236.55  35.5     non-smoker
# 8147          Remote?government               104.25  52.6     non-smoker
# 8149            City?government               245.96  61.5  active_smoker
# 8165            City?government                94.14  38.4     non-smoker
# 8190          Remote?government               211.68   NaN     non-smoker
# 8192            City?government               108.49  23.3           quit
# 8268          Remote?government               124.66  35.3     non-smoker
# 8304          Remote?government                90.12  32.3     non-smoker
# 8406            City?government                87.43  27.7            NaN
# 8438            City?government                88.20  29.8           quit
# 8525            City?government                64.94  31.9           quit
# 8551          Remote?government               104.30  27.2     non-smoker
# 8579          Remote?government               110.37  39.1     non-smoker
# 8685          Remote?government                73.83    31  active_smoker
#
#       TreatmentA  TreatmentB  TreatmentC  TreatmentD job_status_living_area  \
# 1            NaN         NaN         NaN         NaN     (City, government)
# 20           NaN         NaN         NaN         NaN     (City, government)
# 122          NaN         NaN         NaN         NaN     (City, government)
# 159          NaN         NaN         NaN         NaN     (City, government)
# 172          NaN         NaN         NaN         NaN     (City, government)
# 208          NaN         NaN         NaN         NaN     (City, government)
# 222          NaN         NaN         NaN         NaN     (City, government)
# 288          NaN         NaN         NaN         NaN     (City, government)
# 315          NaN         NaN         NaN         NaN     (City, government)
# 520          0.0         0.0         0.0         0.0   (Remote, government)
# 548          NaN         NaN         NaN         NaN   (Remote, government)
# 588          NaN         NaN         NaN         NaN     (City, government)
# 736          NaN         NaN         NaN         NaN   (Remote, government)
# 779          NaN         NaN         NaN         NaN     (City, government)
# 804          NaN         NaN         NaN         NaN     (City, government)
# 857          NaN         NaN         NaN         NaN   (Remote, government)
# 910          NaN         NaN         NaN         NaN   (Remote, government)
# 953          NaN         NaN         NaN         NaN     (City, government)
# 1029         NaN         NaN         NaN         NaN     (City, government)
# 1038         NaN         NaN         NaN         NaN     (City, government)
# 1051         NaN         NaN         NaN         NaN   (Remote, government)
# 1070         NaN         NaN         NaN         NaN     (City, government)
# 1093         NaN         NaN         NaN         NaN   (Remote, government)
# 1234         NaN         NaN         NaN         NaN   (Remote, government)
# 1346         NaN         NaN         NaN         NaN     (City, government)
# 1371         NaN         NaN         NaN         NaN   (Remote, government)
# 1408         NaN         NaN         NaN         NaN   (Remote, government)
# 1474         NaN         NaN         NaN         NaN   (Remote, government)
# 1521         NaN         NaN         NaN         NaN     (City, government)
# 1531         NaN         NaN         NaN         NaN   (Remote, government)
# ...          ...         ...         ...         ...                    ...
# 6786         NaN         NaN         NaN         NaN     (City, government)
# 6801         0.0         0.0         1.0         0.0     (City, government)
# 6833         NaN         NaN         NaN         NaN     (City, government)
# 6952         NaN         NaN         NaN         NaN     (City, government)
# 7117         NaN         NaN         NaN         NaN     (City, government)
# 7132         NaN         NaN         NaN         NaN     (City, government)
# 7209         NaN         NaN         NaN         NaN     (City, government)
# 7228         NaN         NaN         NaN         NaN   (Remote, government)
# 7374         NaN         NaN         NaN         NaN     (City, government)
# 7400         NaN         NaN         NaN         NaN     (City, government)
# 7406         1.0         0.0         0.0         0.0     (City, government)
# 7416         0.0         0.0         0.0         0.0   (Remote, government)
# 7671         NaN         NaN         NaN         NaN   (Remote, government)
# 7746         NaN         NaN         NaN         NaN     (City, government)
# 7800         NaN         NaN         NaN         NaN   (Remote, government)
# 7836         NaN         NaN         NaN         NaN   (Remote, government)
# 8087         NaN         NaN         NaN         NaN   (Remote, government)
# 8147         NaN         NaN         NaN         NaN   (Remote, government)
# 8149         NaN         NaN         NaN         NaN     (City, government)
# 8165         1.0         0.0         0.0         0.0     (City, government)
# 8190         NaN         NaN         NaN         NaN   (Remote, government)
# 8192         NaN         NaN         NaN         NaN     (City, government)
# 8268         NaN         NaN         NaN         NaN   (Remote, government)
# 8304         NaN         NaN         NaN         NaN   (Remote, government)
# 8406         NaN         NaN         NaN         NaN     (City, government)
# 8438         NaN         NaN         NaN         NaN     (City, government)
# 8525         NaN         NaN         NaN         NaN     (City, government)
# 8551         NaN         NaN         NaN         NaN   (Remote, government)
# 8579         NaN         NaN         NaN         NaN   (Remote, government)
# 8685         NaN         NaN         NaN         NaN   (Remote, government)
#
#      job_status living_area
# 1          City  government
# 20         City  government
# 122        City  government
# 159        City  government
# 172        City  government
# 208        City  government
# 222        City  government
# 288        City  government
# 315        City  government
# 520      Remote  government
# 548      Remote  government
# 588        City  government
# 736      Remote  government
# 779        City  government
# 804        City  government
# 857      Remote  government
# 910      Remote  government
# 953        City  government
# 1029       City  government
# 1038       City  government
# 1051     Remote  government
# 1070       City  government
# 1093     Remote  government
# 1234     Remote  government
# 1346       City  government
# 1371     Remote  government
# 1408     Remote  government
# 1474     Remote  government
# 1521       City  government
# 1531     Remote  government
# ...         ...         ...
# 6786       City  government
# 6801       City  government
# 6833       City  government
# 6952       City  government
# 7117       City  government
# 7132       City  government
# 7209       City  government
# 7228     Remote  government
# 7374       City  government
# 7400       City  government
# 7406       City  government
# 7416     Remote  government
# 7671     Remote  government
# 7746       City  government
# 7800     Remote  government
# 7836     Remote  government
# 8087     Remote  government
# 8147     Remote  government
# 8149       City  government
# 8165       City  government
# 8190     Remote  government
# 8192       City  government
# 8268     Remote  government
# 8304     Remote  government
# 8406       City  government
# 8438       City  government
# 8525       City  government
# 8551     Remote  government
# 8579     Remote  government
# 8685     Remote  government
#
# [138 rows x 16 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# It appears that living_area and job_status are sometimes filled in the wrong columns
# </div>
#
# Hence, we need to write a function to swap them.
#
# But before we do that, we designate the variables we want to keep.

# %%
living_area_keep = ["city", "remote", "private_sector", "business_owner",
                    "parental_leave", "government", "unemployed"]

# %%
stk = stk[(stk["living_area"].isin(living_area_keep))]
stk.shape
# Out:
# (8706, 16)

# %% [markdown]
# ---
# __Job status__
# ---

# %% [markdown]
# We take a similar approach to the `job_status`.

# %%
stk["job_status"] = stk["job_status"].apply(lambda x: x.lower())

# %%
print(stk["job_status"].value_counts())
print(stk["job_status"].unique())
# Out:
# private_sector    4293
# business_owner    1143
# parental_leave    1085
# government         933
# city               621
# remote             589
# unemployed          28
# private sector       3
#                      3
# business owner       2
# govt.                2
# r                    1
# private              1
# biz                  1
# c                    1
# Name: job_status, dtype: int64
# ['private_sector' 'city' 'business_owner' 'government' 'parental_leave'
#  'remote' 'unemployed' 'govt.' '' 'business owner' 'private sector' 'biz'
#  'private' 'r' 'c']

# %%
stk.loc[stk["job_status"] == "parental leave", "job_status"] = "parental_leave"
stk.loc[stk["job_status"] == "private sector", "job_status"] = "private_sector"
stk.loc[stk["job_status"] == "private", "job_status"] = "private_sector"
stk.loc[stk["job_status"] == "govt.", "job_status"] = "government"
stk.loc[stk["job_status"] == "remotee", "job_status"] = "remote"
print(stk["job_status"].value_counts())
# Out:
# private_sector    4297
# business_owner    1143
# parental_leave    1085
# government         935
# city               621
# remote             589
# unemployed          28
#                      3
# business owner       2
# r                    1
# biz                  1
# c                    1
# Name: job_status, dtype: int64

# %%
# Variables to be dropped
job_status_keep = ["private_sector", "business_owner", "parental_leave", 
                   "government", "city", "remote", "unemployed"]

# %%
stk = stk[(stk["job_status"].isin(job_status_keep))]
stk.shape
# Out:
# (8698, 16)

# %% [markdown]
# __Now let's swap the variables around__

# %%
job_status_correct = ["private_sector", "business_owner", "parental_leave", 
                   "government", "unemployed"]
living_area_correct = ["city", "remote"]

# %%
stk["job_status_corr"], stk["living_area_corr"] = zip(*stk.apply(lambda x:\
            swap_job_living(x.job_status, x.living_area,
                           job_status_correct, living_area_correct), axis=1))
# Out:
# job: private_sector
# area: remote
# don't swap
# job: city
# area: government
# swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: remote
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: government
# swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: parental_leave
# swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: government
# area: city
# don't swap
# job: city
# area: government
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: remote
# area: business_owner
# swap
# job: government
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: government
# swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: city
# area: government
# swap
# job: remote
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: unemployed
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: government
# swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: government
# swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: city
# area: private_sector
# swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: business_owner
# swap
# job: remote
# area: private_sector
# swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: unemployed
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: parental_leave
# area: city
# don't swap
# job: city
# area: government
# swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: remote
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: government
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: business_owner
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: business_owner
# swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: remote
# area: parental_leave
# swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: city
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: parental_leave
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: remote
# area: business_owner
# swap
# job: remote
# area: private_sector
# swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: city
# area: business_owner
# swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: city
# area: parental_leave
# swap
# job: city
# area: private_sector
# swap
# job: remote
# area: business_owner
# swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: government
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: remote
# area: government
# swap
# job: government
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: government
# swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: city
# area: business_owner
# swap
# job: parental_leave
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: city
# area: private_sector
# swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: parental_leave
# area: city
# don't swap
# job: city
# area: parental_leave
# swap
# job: remote
# area: private_sector
# swap
# job: government
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: remote
# area: parental_leave
# swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: remote
# area: business_owner
# swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: remote
# area: government
# swap
# job: remote
# area: private_sector
# swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: parental_leave
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: government
# swap
# job: remote
# area: private_sector
# swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: remote
# area: private_sector
# swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: government
# swap
# job: parental_leave
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: parental_leave
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: parental_leave
# swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: city
# area: parental_leave
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: government
# swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: remote
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: parental_leave
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: remote
# area: parental_leave
# swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: remote
# area: government
# swap
# job: government
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: parental_leave
# swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: government
# swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: city
# area: parental_leave
# swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: business_owner
# swap
# job: business_owner
# area: remote
# don't swap
# job: city
# area: parental_leave
# swap
# job: remote
# area: business_owner
# swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: city
# area: parental_leave
# swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: remote
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: government
# swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: city
# area: government
# swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: government
# swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: remote
# area: business_owner
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: city
# area: government
# swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: government
# swap
# job: government
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: parental_leave
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# ...
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: unemployed
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: business_owner
# swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: city
# area: government
# swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: city
# area: business_owner
# swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: city
# area: government
# swap
# job: business_owner
# area: remote
# don't swap
# job: unemployed
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: parental_leave
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: government
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: city
# area: parental_leave
# swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: remote
# area: business_owner
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: remote
# area: government
# swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: remote
# area: government
# swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: city
# area: business_owner
# swap
# job: government
# area: remote
# don't swap
# job: unemployed
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: unemployed
# area: city
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: remote
# area: parental_leave
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: parental_leave
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: city
# area: business_owner
# swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: government
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: city
# area: private_sector
# swap
# job: government
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: business_owner
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: remote
# area: government
# swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: government
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: parental_leave
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: remote
# area: private_sector
# swap
# job: city
# area: private_sector
# swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: business_owner
# area: remote
# don't swap
# job: parental_leave
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: city
# don't swap
# job: private_sector
# area: remote
# don't swap
# job: city
# area: private_sector
# swap
# job: remote
# area: private_sector
# swap
# job: government
# area: remote
# don't swap

# %%
print(stk["job_status_corr"].value_counts())
print(stk["living_area_corr"].value_counts())
# Out:
# private_sector    5015
# business_owner    1321
# parental_leave    1255
# government        1073
# unemployed          34
# Name: job_status_corr, dtype: int64
# city      4372
# remote    4326
# Name: living_area_corr, dtype: int64

# %% [markdown]
# ### Sex and Age

# %% [markdown]
# <div class="alert alert-block alert-info">
# Sex and Age variable is a little messy. Let's clean this up.
# </div>

# %%
stk["sex and age"].unique()
# Out:
# array(['F, 36', 'F, 40', 'M, 59', '33, F', 'F, 22', 'M, 60', 'F, 83',
#        'M, 47', 'F, 82', 'F, 49', 'M, 58', 'M, 82', 'M, 4.88', 'F, 38',
#        'M, 50', 'F, 84', 'F, 68', 'M, 40', 'M, 52', 'M, 62', 'M, 35',
#        '32, F', 'M, 14', 'F, 35', 'F, 43', 'M, 43', 'M, 12', 'F, 55',
#        'F, 33', 'F, 30', '36, M', 'F, 56', 'F, 78', 'M, 69', 'M, 48',
#        'F, 64', 'F, 16', 'F, 63', 'F, 58', 'M, 26', 'F, 29', 'F, 61',
#        'M, 79', 'M, 20', 'F, 5', 'F, 42', 'F, 72', 'F, 48', 'M, 73',
#        'M, 21', 'M, 55', 'M, 34', 'F, 27', 'F, 41', 'F, 52', 'M, 31',
#        'F, 47', 'F, 18', 'M, 85', 'M, 78', 'M, 3.72', 'M, 51', '50, M',
#        'F, 4.08', 'F, 71', '63, F', 'F, 76', 'M, 45', 'M, 67', 'F, 60',
#        'M, 19', 'F, 45', 'M, 17', 'F, 46', 'M, 7', 'F, 62', 'M, 65',
#        'F, 66', 'F, 81', 'F, 50', '65, F', 'M, 54', 'F, 39', 'F, 3.32',
#        'M, 6', 'F, 53', 'F, 28', 'F, 37', 'F, 57', 'F, 24', 'F, 65',
#        'F, 26', 'F, 20', 'M, 8', 'F, 32', 'F, 80', '51, F', 'F, 4',
#        'F, 59', 'F, 51', 'M, 13', 'F, 44', '35, M', 'F, 14', '4.72, F',
#        'F, 69', 'M, 64', 'M, 28', 'F, 34', '67, F', 'M, 25', '80, F',
#        'F, 3.88', 'M, 44', 'F, 74', 'F, 31', 'M, 71', '60, M', 'M, 76',
#        'M, 33', 'M, 68', 'M, 80', '57, F', 'M, 37', 'F, 21', 'M, 46',
#        'M, 49', '77, F', 'M, 74', 'F, 4.64', 'F, 67', '20, F', 'F, 15',
#        '37, F', 'M, 81', 'F, 17', '59, M', 'F, 13', 'M, 56', '34, M',
#        '9, F', 'F, 85', 'M, 18', 'F, 4.24', '16, F', 'M, 32', '72, F',
#        'F, 23', 'F, 7', 'M, 63', 'M, 5', 'M, 84', 'F, 70', 'F, 54',
#        'F, 25', 'M, 57', 'm, 53', 'M, 3.32', 'M, 42', 'M, 11', '26, F',
#        'F, 77', 'F, 12', 'F, 73', 'M, 39', 'M, 22', '30, F', '41, M',
#        'M, 3.56', 'F, 75', 'M, 38', '85, M', 'M, 4', 'M, 4.32', 'M, 61',
#        '11, F', 'M, 36', 'M, 3.48', 'M, 66', '78, M', 'F, 11', 'M, 15',
#        'M, 4.08', 'Other, 14', '12, F', 'F, 19', '47, F', 'F, 79',
#        '56, F', 'M, 75', 'M, 53', 'F, 3.64', '4.4, F', '55, F', '39, M',
#        'Other, 30', '83, F', 'M, 24', 'M, 29', 'M, 70', 'F, 8', '42, M',
#        'M, 16', '52, M', '41, F', '52, F', 'M, 27', '27, M', '57, M',
#        '40, F', '58, F', 'M, 41', '66, M', '31, F', '83, M', 'F, 6',
#        '56, M', '68, F', '65, M', '5, F', '59, F', '43, F', 'F, 3.72',
#        'M, 4.16', '3.56, F', '44, F', '15, M', 'M, 10', '6, M', 'F, 4.72',
#        'M, 83', '14, M', '42, F', '82, F', '23, M', 'Other, 54', 'M, 30',
#        '30, M', 'F, 4.32', '32, M', 'M, 3.8', 'M, 3.64', '23, F', 'F, 10',
#        'F, 3.56', '62, F', '69, F', 'F, 4.48', '73, F', '22, F', '19, F',
#        '6, F', '54, F', '81, F', 'M, 4.4', '27, F', '85, F', '36, F',
#        'M, 77', '64, M', '71, F', '78, F', '40, M', 'F, 9', '13, M',
#        'M, 3.08', '45, F', '4.56, M', '46, F', '75, F', 'M, 4.56',
#        '17, F', '61, F', '7, F', '10, F', 'M, 23', '25, F', 'M, 9',
#        'F, 3.16', nan, 'F, 3.08', '55, M', '64, F', '44, M', 'M, 4.8',
#        '46, M', 'F, 4.56', '58, M', 'M, 72', '24, F', '38, F', '7, M',
#        'M, 3.24', '3.64, M', 'F, 4.4', '53, M', '21, F', '51, M', '17, M',
#        '5, M', '26, M', '66, F', '9, M', '33, M', '24, M', 'M, 4.72',
#        'M, 3.4', '71, M', 'M, 3.88', 'f, 33', '39, F', '19, M', '35, F',
#        '67, M', '62, M', '50, F', '3.72, M', 'F, 3.24', 'F, 4.16',
#        '74, F', '47, M', '49, F', 'M, 4.48', 'M, fifteen', '21, M',
#        '10, M', 'F, 4.88', '3.88, M', '45, M', '79, F', '14, F', '54, M',
#        '28, F', '31, M', '68, M', 'M, sixty-seven', '48, M', 'F, 4.8',
#        'M, 4.24', '20, M', '49, M', '53, F', '34, F', 'F, 3.8', '70, F',
#        '15, F', 'Other, 29', '61, M', 'M, 4.64', '84, F', '25, M',
#        'F, eight', '84, M', '48, F', '3.8, M', 'F, 3.48', '12, M',
#        'M, 3.16', '8, F', '43, M', '29, F', '81, M', 'F, fifty',
#        'FEMALE, 34', 'MALE, 43', '76, M', 'F, 3.4', '82, M', '80, M',
#        '69, M', '37, M', '60, F', '3.8, F', '74, M', '76, F', '77, M',
#        '63, M', '4.24, M', 'MALE, 76', '72, M', '70, M', '3.64, F',
#        '18, F', '73, M', '3.08, F', '75, M', '4, M', '38, M', '8, M',
#        'F, sixty-seven', 'F, sixty three', '4.48, M', '22, M',
#        'M, twenty two'], dtype=object)

# %%
stk["sex_and_age"] = stk["sex and age"].apply(split_row, args=",")
stk["sex"], stk["age"] = zip(*stk['sex_and_age'].map(split_tup))
stk.head()
# Out:
#       id sex and age  high_BP  heart_condition_detected_2017  married  \
# 0  33327       F, 36      0.0                            0.0      1.0
# 1    839       F, 40      0.0                            0.0      1.0
# 2  11127       M, 59      0.0                            0.0      1.0
# 3  20768       33, F      0.0                            0.0      1.0
# 4  37774       F, 22      0.0                            0.0      0.0
#
#   job_status and living_area  average_blood_sugar   BMI  smoker_status  \
# 0      private_sector?Remote                76.05  33.4  active_smoker
# 1            City?government                73.77  30.1     non-smoker
# 2      business_owner?Remote                62.95  30.8            NaN
# 3        private_sector?City                68.81  36.5           quit
# 4        private_sector?City               122.89  30.8  active_smoker
#
#    TreatmentA  ...  TreatmentC  TreatmentD    job_status_living_area  \
# 0         NaN  ...         NaN         NaN  (private_sector, Remote)
# 1         NaN  ...         NaN         NaN        (City, government)
# 2         NaN  ...         NaN         NaN  (business_owner, Remote)
# 3         NaN  ...         NaN         NaN    (private_sector, City)
# 4         NaN  ...         NaN         NaN    (private_sector, City)
#
#        job_status living_area job_status_corr living_area_corr sex_and_age  \
# 0  private_sector      remote  private_sector           remote    (F,  36)
# 1            city  government      government             city    (F,  40)
# 2  business_owner      remote  business_owner           remote    (M,  59)
# 3  private_sector        city  private_sector             city    (33,  F)
# 4  private_sector        city  private_sector             city    (F,  22)
#
#   sex  age
# 0   F   36
# 1   F   40
# 2   M   59
# 3  33    F
# 4   F   22
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Sex Variable
#
# Now let's deal with the `sex` variable separately

# %%
stk["sex"] = stk["sex"].apply(lambda x: x.lower())

print(stk["sex"].value_counts())
print(stk["sex"].unique())

stk.loc[stk["sex"] == "male", "sex"] = "m"
stk.loc[stk["sex"] == "mmale", "sex"] = "m"
stk.loc[stk["sex"] == "mm", "sex"] = "m"
stk.loc[stk["sex"] == "female", "sex"] = "f"
stk.loc[stk["sex"] == "femalle", "sex"] = "f"
# Out:
# f         4808
# m         3275
# 39          16
# 64          16
# 5           15
# 63          14
# 67          14
# 55          14
# 52          12
# 24          12
# 44          11
# 43          11
# 22          11
# 42          11
# 57          10
# 54          10
# 53          10
# 81          10
# 65          10
# 23          10
# 68          10
# 27           9
# 61           9
# 32           9
# 59           9
# 51           9
# 46           9
# 17           9
# n            9
# 69           9
#           ...
# 70           4
# 9            4
# other        4
# 49           4
# 29           4
# 7            4
# 18           3
# 26           3
# 74           3
# 28           3
# 8            3
# 20           3
# male         3
# 66           3
# 79           2
# 3.64         2
# 3.8          2
# 73           2
# 13           2
# 4.72         1
# 4.48         1
# 4.4          1
# female       1
# 3.56         1
# 3.08         1
# 4.24         1
# 3.88         1
# 4.56         1
# 4            1
# 3.72         1
# Name: sex, Length: 99, dtype: int64
# ['f' 'm' '33' '32' '36' '50' '63' '65' '51' '35' '4.72' '67' '80' '60'
#  '57' '77' '20' '37' '59' '34' '9' '16' '72' '26' '30' '41' '85' '11' '78'
#  'other' '12' '47' '56' '4.4' '55' '39' '83' '42' '52' '27' '40' '58' '66'
#  '31' '68' '5' '43' '3.56' '44' '15' '6' '14' '82' '23' '62' '69' '73'
#  '22' '19' '54' '81' '64' '71' '13' '45' '4.56' '46' '75' '17' '61' '7'
#  '10' '25' 'n' '24' '38' '3.64' '53' '21' '3.72' '74' '49' '3.88' '79'
#  '28' '48' '70' '84' '3.8' '8' '29' 'female' 'male' '76' '4.24' '18'
#  '3.08' '4' '4.48']

# %%
stk[stk["sex"] == "n"][["sex and age", "sex", "age"]].head()
# Out:
#      sex and age sex age
# 1663         NaN   n   a
# 2253         NaN   n   a
# 2257         NaN   n   a
# 2503         NaN   n   a
# 2943         NaN   n   a

# %%
sex_not_keep = ["", "other", "n"] 

# We can't remove the unwanted numbers out until we swap them with age
# So we instead filter those that we don't want to keep.

# %%
stk = stk[~stk["sex"].isin(sex_not_keep)]
stk.shape
# Out:
# (8685, 21)

# %% [markdown]
# ### Age Variable

# %%
stk["age"] = stk["age"].apply(lambda x: x.lower())
stk["age"] = stk["age"].apply(lambda x: x.strip())

print(stk["age"].value_counts())
print(stk["age"].unique())
# Out:
# f              370
# m              228
# 54             150
# 55             145
# 50             143
# 48             139
# 81             139
# 53             135
# 47             134
# 59             131
# 62             130
# 63             129
# 49             129
# 43             126
# 51             125
# 52             121
# 58             120
# 44             120
# 56             120
# 60             119
# 61             116
# 45             115
# 64             113
# 57             113
# 41             113
# 42             111
# 66             110
# 8              108
# 34             107
# 36             104
#               ...
# 77              47
# 3.56            15
# 3.32            13
# 3.64            13
# 3.72            12
# 3.24            12
# 4.08            12
# 3.8             12
# 4.56            12
# 4.4             11
# 3.88            11
# 3.48            11
# 4.88            10
# 4.32            10
# 4.24             9
# 4.64             9
# 4.72             9
# 4.16             8
# 4.8              8
# 4                7
# 4.48             5
# 3.4              5
# 3.16             4
# 3.08             3
# sixty-seven      2
# sixty three      1
# fifteen          1
# fifty            1
# eight            1
# twenty two       1
# Name: age, Length: 112, dtype: int64
# ['36' '40' '59' 'f' '22' '60' '83' '47' '82' '49' '58' '4.88' '38' '50'
#  '84' '68' '52' '62' '35' '14' '43' '12' '55' '33' '30' 'm' '56' '78' '69'
#  '48' '64' '16' '63' '26' '29' '61' '79' '20' '5' '42' '72' '73' '21' '34'
#  '27' '41' '31' '18' '85' '3.72' '51' '4.08' '71' '76' '45' '67' '19' '17'
#  '46' '7' '65' '66' '81' '54' '39' '3.32' '6' '53' '28' '37' '57' '24' '8'
#  '32' '80' '4' '13' '44' '25' '3.88' '74' '4.64' '15' '4.24' '23' '70'
#  '11' '77' '3.56' '75' '4.32' '3.48' '3.64' '4.16' '10' '4.72' '3.8'
#  '4.48' '4.4' '9' '3.08' '4.56' '3.16' '4.8' '3.24' '3.4' 'fifteen'
#  'sixty-seven' 'eight' 'fifty' 'sixty three' 'twenty two']

# %%
stk.loc[stk["age"] == 'sixteen', "age"] = '16'
stk.loc[stk["age"] == 'eleven', "age"] = '11'
stk.loc[stk["age"] == 'fifty', "age"] = '50'
stk.loc[stk["age"] == 'seventy seven', "age"] = '77'
stk.loc[stk["age"] == 'sixteen', "age"] = '16'
stk.loc[stk["age"] == 'forty', "age"] = '40'
stk.loc[stk["age"] == 'sixx', "age"] = '6'
stk.loc[stk["age"] == 'eight', "age"] = '8'
stk.loc[stk["age"] == 'seven', "age"] = '7'
stk.loc[stk["age"] == 'eighty fivee', "age"] = '85'
stk.loc[stk["age"] == 'six', "age"] = '6'
stk.loc[stk["age"] == 'thirtythree', "age"] = '33'
stk.loc[stk["age"] == 'fifteen', "age"] = '15'
stk.loc[stk["age"] == 'sixty-seven', "age"] = '67'
stk.loc[stk["age"] == 'eight', "age"] = '8'
stk.loc[stk["age"] == '50', "age"] = '50'
stk.loc[stk["age"] == 'sixty three', "age"] = '63'
stk.loc[stk["age"] == 'twenty two', "age"] = '22'

# %%
stk.columns
# Out:
# Index(['id', 'sex and age', 'high_BP', 'heart_condition_detected_2017',
#        'married', 'job_status and living_area', 'average_blood_sugar', 'BMI',
#        'smoker_status', 'TreatmentA', 'TreatmentB', 'TreatmentC', 'TreatmentD',
#        'job_status_living_area', 'job_status', 'living_area',
#        'job_status_corr', 'living_area_corr', 'sex_and_age', 'sex', 'age'],
#       dtype='object')

# %%
print(stk["age"].value_counts())
print(stk["age"].unique())
# Out:
# f       370
# m       228
# 54      150
# 55      145
# 50      144
# 81      139
# 48      139
# 53      135
# 47      134
# 59      131
# 63      130
# 62      130
# 49      129
# 43      126
# 51      125
# 52      121
# 56      120
# 44      120
# 58      120
# 60      119
# 61      116
# 45      115
# 41      113
# 57      113
# 64      113
# 42      111
# 66      110
# 8       109
# 34      107
# 67      104
#        ...
# 79       61
# 76       57
# 10       56
# 7        56
# 14       54
# 9        54
# 77       47
# 3.56     15
# 3.32     13
# 3.64     13
# 3.72     12
# 3.24     12
# 4.08     12
# 4.56     12
# 3.8      12
# 3.48     11
# 4.4      11
# 3.88     11
# 4.32     10
# 4.88     10
# 4.64      9
# 4.72      9
# 4.24      9
# 4.16      8
# 4.8       8
# 4         7
# 4.48      5
# 3.4       5
# 3.16      4
# 3.08      3
# Name: age, Length: 106, dtype: int64
# ['36' '40' '59' 'f' '22' '60' '83' '47' '82' '49' '58' '4.88' '38' '50'
#  '84' '68' '52' '62' '35' '14' '43' '12' '55' '33' '30' 'm' '56' '78' '69'
#  '48' '64' '16' '63' '26' '29' '61' '79' '20' '5' '42' '72' '73' '21' '34'
#  '27' '41' '31' '18' '85' '3.72' '51' '4.08' '71' '76' '45' '67' '19' '17'
#  '46' '7' '65' '66' '81' '54' '39' '3.32' '6' '53' '28' '37' '57' '24' '8'
#  '32' '80' '4' '13' '44' '25' '3.88' '74' '4.64' '15' '4.24' '23' '70'
#  '11' '77' '3.56' '75' '4.32' '3.48' '3.64' '4.16' '10' '4.72' '3.8'
#  '4.48' '4.4' '9' '3.08' '4.56' '3.16' '4.8' '3.24' '3.4']

# %%
age_not_keep = ['', 'other', 'a']

# %%
stk = stk[~stk["age"].isin(age_not_keep)]
stk.shape
# Out:
# (8685, 21)

# %%
sex_correct = ["f", "m"]

stk["sex_corr"], stk["age_corr"] = zip(*stk.apply(lambda x:\
            swap_sex_age(x.sex, x.age, sex_correct), axis=1))
# Out:
# sex: f
# age: 36
# don't swap
# sex: f
# age: 40
# don't swap
# sex: m
# age: 59
# don't swap
# sex: 33
# age: f
# swap
# sex: f
# age: 22
# don't swap
# sex: m
# age: 60
# don't swap
# sex: f
# age: 83
# don't swap
# sex: m
# age: 47
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 49
# don't swap
# sex: m
# age: 58
# don't swap
# sex: m
# age: 82
# don't swap
# sex: m
# age: 4.88
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 38
# don't swap
# sex: m
# age: 50
# don't swap
# sex: f
# age: 84
# don't swap
# sex: f
# age: 68
# don't swap
# sex: m
# age: 40
# don't swap
# sex: m
# age: 52
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 68
# don't swap
# sex: m
# age: 35
# don't swap
# sex: 32
# age: f
# swap
# sex: m
# age: 14
# don't swap
# sex: m
# age: 40
# don't swap
# sex: f
# age: 35
# don't swap
# sex: f
# age: 43
# don't swap
# sex: m
# age: 47
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 12
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 30
# don't swap
# sex: 36
# age: m
# swap
# sex: f
# age: 56
# don't swap
# sex: f
# age: 78
# don't swap
# sex: m
# age: 69
# don't swap
# sex: m
# age: 48
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 16
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 58
# don't swap
# sex: m
# age: 52
# don't swap
# sex: m
# age: 26
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 61
# don't swap
# sex: m
# age: 79
# don't swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 5
# don't swap
# sex: f
# age: 42
# don't swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 48
# don't swap
# sex: m
# age: 73
# don't swap
# sex: f
# age: 30
# don't swap
# sex: m
# age: 21
# don't swap
# sex: m
# age: 55
# don't swap
# sex: m
# age: 34
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 40
# don't swap
# sex: f
# age: 41
# don't swap
# sex: f
# age: 52
# don't swap
# sex: m
# age: 31
# don't swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 79
# don't swap
# sex: f
# age: 18
# don't swap
# sex: m
# age: 85
# don't swap
# sex: m
# age: 78
# don't swap
# sex: m
# age: 3.72
# don't swap
# sex: m
# age: 51
# don't swap
# sex: 50
# age: m
# swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 4.08
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 71
# don't swap
# sex: 63
# age: f
# swap
# sex: m
# age: 60
# don't swap
# sex: m
# age: 79
# don't swap
# sex: f
# age: 76
# don't swap
# sex: m
# age: 45
# don't swap
# sex: m
# age: 67
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 19
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 59
# don't swap
# sex: m
# age: 17
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 42
# don't swap
# sex: f
# age: 46
# don't swap
# sex: f
# age: 40
# don't swap
# sex: m
# age: 7
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 65
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 60
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 50
# don't swap
# sex: 65
# age: f
# swap
# sex: m
# age: 45
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 54
# don't swap
# sex: f
# age: 39
# don't swap
# sex: f
# age: 3.32
# don't swap
# sex: m
# age: 6
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 37
# don't swap
# sex: f
# age: 57
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 65
# don't swap
# sex: m
# age: 12
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 20
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 32
# don't swap
# sex: m
# age: 52
# don't swap
# sex: f
# age: 63
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 37
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 38
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 16
# don't swap
# sex: f
# age: 41
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 40
# don't swap
# sex: f
# age: 80
# don't swap
# sex: m
# age: 51
# don't swap
# sex: 51
# age: f
# swap
# sex: f
# age: 4
# don't swap
# sex: m
# age: 47
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 59
# don't swap
# sex: m
# age: 14
# don't swap
# sex: f
# age: 68
# don't swap
# sex: f
# age: 51
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 59
# don't swap
# sex: 35
# age: m
# swap
# sex: m
# age: 59
# don't swap
# sex: f
# age: 16
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 14
# don't swap
# sex: f
# age: 28
# don't swap
# sex: 4.72
# age: f
# swap
# sex: f
# age: 69
# don't swap
# sex: m
# age: 64
# don't swap
# sex: f
# age: 78
# don't swap
# sex: m
# age: 28
# don't swap
# sex: f
# age: 71
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 38
# don't swap
# sex: f
# age: 34
# don't swap
# sex: f
# age: 47
# don't swap
# sex: 67
# age: f
# swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 39
# don't swap
# sex: 80
# age: f
# swap
# sex: m
# age: 85
# don't swap
# sex: f
# age: 3.88
# don't swap
# sex: m
# age: 44
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 74
# don't swap
# sex: f
# age: 31
# don't swap
# sex: m
# age: 45
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 48
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 41
# don't swap
# sex: f
# age: 35
# don't swap
# sex: f
# age: 40
# don't swap
# sex: f
# age: 16
# don't swap
# sex: m
# age: 45
# don't swap
# sex: f
# age: 44
# don't swap
# sex: m
# age: 71
# don't swap
# sex: 60
# age: m
# swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 30
# don't swap
# sex: m
# age: 76
# don't swap
# sex: f
# age: 36
# don't swap
# sex: m
# age: 33
# don't swap
# sex: f
# age: 31
# don't swap
# sex: m
# age: 6
# don't swap
# sex: m
# age: 68
# don't swap
# sex: f
# age: 43
# don't swap
# sex: m
# age: 80
# don't swap
# sex: 57
# age: f
# swap
# sex: f
# age: 35
# don't swap
# sex: m
# age: 37
# don't swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 71
# don't swap
# sex: f
# age: 21
# don't swap
# sex: m
# age: 46
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 76
# don't swap
# sex: f
# age: 45
# don't swap
# sex: 77
# age: f
# swap
# sex: f
# age: 61
# don't swap
# sex: m
# age: 74
# don't swap
# sex: f
# age: 4.64
# don't swap
# sex: m
# age: 8
# don't swap
# sex: m
# age: 4.88
# don't swap
# sex: f
# age: 67
# don't swap
# sex: 20
# age: f
# swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 39
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 42
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 15
# don't swap
# sex: f
# age: 60
# don't swap
# sex: f
# age: 16
# don't swap
# sex: m
# age: 60
# don't swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 16
# don't swap
# sex: 37
# age: f
# swap
# sex: f
# age: 24
# don't swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 65
# don't swap
# sex: f
# age: 16
# don't swap
# sex: f
# age: 17
# don't swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 80
# don't swap
# sex: f
# age: 18
# don't swap
# sex: 59
# age: m
# swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 76
# don't swap
# sex: f
# age: 13
# don't swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 67
# don't swap
# sex: m
# age: 68
# don't swap
# sex: m
# age: 40
# don't swap
# sex: m
# age: 35
# don't swap
# sex: m
# age: 56
# don't swap
# sex: m
# age: 85
# don't swap
# sex: f
# age: 65
# don't swap
# sex: 34
# age: m
# swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 5
# don't swap
# sex: m
# age: 46
# don't swap
# sex: 9
# age: f
# swap
# sex: f
# age: 85
# don't swap
# sex: f
# age: 24
# don't swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 58
# don't swap
# sex: f
# age: 30
# don't swap
# sex: m
# age: 18
# don't swap
# sex: f
# age: 4.24
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 15
# don't swap
# sex: f
# age: 41
# don't swap
# sex: 16
# age: f
# swap
# sex: f
# age: 66
# don't swap
# sex: m
# age: 32
# don't swap
# sex: f
# age: 35
# don't swap
# sex: f
# age: 51
# don't swap
# sex: m
# age: 19
# don't swap
# sex: 72
# age: f
# swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 23
# don't swap
# sex: f
# age: 42
# don't swap
# sex: f
# age: 74
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 7
# don't swap
# sex: m
# age: 63
# don't swap
# sex: m
# age: 5
# don't swap
# sex: m
# age: 55
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 5
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 84
# don't swap
# sex: f
# age: 22
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 7
# don't swap
# sex: m
# age: 37
# don't swap
# sex: f
# age: 74
# don't swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 74
# don't swap
# sex: f
# age: 16
# don't swap
# sex: f
# age: 67
# don't swap
# sex: f
# age: 80
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 70
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 50
# don't swap
# sex: m
# age: 32
# don't swap
# sex: f
# age: 38
# don't swap
# sex: m
# age: 45
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 83
# don't swap
# sex: m
# age: 25
# don't swap
# sex: m
# age: 64
# don't swap
# sex: m
# age: 52
# don't swap
# sex: m
# age: 21
# don't swap
# sex: m
# age: 57
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 38
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 31
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 35
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 40
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 21
# don't swap
# sex: m
# age: 3.32
# don't swap
# sex: f
# age: 41
# don't swap
# sex: m
# age: 42
# don't swap
# sex: m
# age: 82
# don't swap
# sex: m
# age: 11
# don't swap
# sex: f
# age: 13
# don't swap
# sex: m
# age: 69
# don't swap
# sex: 26
# age: f
# swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 77
# don't swap
# sex: f
# age: 16
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 31
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 4.64
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 12
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 80
# don't swap
# sex: m
# age: 21
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 79
# don't swap
# sex: f
# age: 73
# don't swap
# sex: f
# age: 40
# don't swap
# sex: m
# age: 39
# don't swap
# sex: f
# age: 43
# don't swap
# sex: m
# age: 34
# don't swap
# sex: f
# age: 39
# don't swap
# sex: m
# age: 22
# don't swap
# sex: f
# age: 5
# don't swap
# sex: 30
# age: f
# swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 67
# don't swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 79
# don't swap
# sex: m
# age: 55
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 68
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 60
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 51
# don't swap
# sex: m
# age: 11
# don't swap
# sex: m
# age: 26
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 85
# don't swap
# sex: 41
# age: m
# swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 51
# don't swap
# sex: m
# age: 3.56
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 75
# don't swap
# sex: f
# age: 59
# don't swap
# sex: m
# age: 38
# don't swap
# sex: f
# age: 14
# don't swap
# sex: f
# age: 60
# don't swap
# sex: f
# age: 57
# don't swap
# sex: f
# age: 58
# don't swap
# sex: 85
# age: m
# swap
# sex: f
# age: 41
# don't swap
# sex: f
# age: 64
# don't swap
# sex: m
# age: 4
# don't swap
# sex: f
# age: 71
# don't swap
# sex: f
# age: 65
# don't swap
# sex: m
# age: 28
# don't swap
# sex: m
# age: 6
# don't swap
# sex: f
# age: 50
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 18
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 72
# don't swap
# sex: m
# age: 4.32
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 14
# don't swap
# sex: 11
# age: f
# swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 21
# don't swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 75
# don't swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 36
# don't swap
# sex: f
# age: 46
# don't swap
# sex: m
# age: 3.48
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 77
# don't swap
# sex: f
# age: 46
# don't swap
# sex: f
# age: 61
# don't swap
# sex: m
# age: 33
# don't swap
# sex: m
# age: 55
# don't swap
# sex: m
# age: 79
# don't swap
# sex: m
# age: 80
# don't swap
# sex: m
# age: 19
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 61
# don't swap
# sex: m
# age: 66
# don't swap
# sex: 78
# age: m
# swap
# sex: f
# age: 11
# don't swap
# sex: m
# age: 51
# don't swap
# sex: m
# age: 36
# don't swap
# sex: m
# age: 22
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 21
# don't swap
# sex: m
# age: 52
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 38
# don't swap
# sex: f
# age: 23
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 15
# don't swap
# sex: f
# age: 68
# don't swap
# sex: f
# age: 80
# don't swap
# sex: m
# age: 4.08
# don't swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 66
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 68
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 74
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 39
# don't swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 56
# don't swap
# sex: 12
# age: f
# swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 25
# don't swap
# sex: m
# age: 40
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 15
# don't swap
# sex: f
# age: 19
# don't swap
# sex: m
# age: 48
# don't swap
# sex: 47
# age: f
# swap
# sex: f
# age: 58
# don't swap
# sex: m
# age: 50
# don't swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 20
# don't swap
# sex: m
# age: 6
# don't swap
# sex: m
# age: 33
# don't swap
# sex: f
# age: 16
# don't swap
# sex: f
# age: 79
# don't swap
# sex: 56
# age: f
# swap
# sex: f
# age: 74
# don't swap
# sex: m
# age: 20
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 69
# don't swap
# sex: m
# age: 45
# don't swap
# sex: f
# age: 84
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 75
# don't swap
# sex: m
# age: 53
# don't swap
# sex: m
# age: 39
# don't swap
# sex: m
# age: 68
# don't swap
# sex: f
# age: 70
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 63
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 8
# don't swap
# sex: m
# age: 51
# don't swap
# sex: f
# age: 3.64
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 44
# don't swap
# sex: m
# age: 65
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 60
# don't swap
# sex: 4.4
# age: f
# swap
# sex: m
# age: 42
# don't swap
# sex: 55
# age: f
# swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 40
# don't swap
# sex: f
# age: 57
# don't swap
# sex: 39
# age: m
# swap
# sex: m
# age: 46
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 77
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 55
# don't swap
# sex: 30
# age: f
# swap
# sex: m
# age: 66
# don't swap
# sex: f
# age: 38
# don't swap
# sex: m
# age: 6
# don't swap
# sex: m
# age: 6
# don't swap
# sex: f
# age: 85
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 43
# don't swap
# sex: m
# age: 36
# don't swap
# sex: f
# age: 12
# don't swap
# sex: m
# age: 6
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 70
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 56
# don't swap
# sex: f
# age: 71
# don't swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 46
# don't swap
# sex: f
# age: 53
# don't swap
# sex: 83
# age: f
# swap
# sex: m
# age: 11
# don't swap
# sex: f
# age: 24
# don't swap
# sex: m
# age: 24
# don't swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 29
# don't swap
# sex: m
# age: 7
# don't swap
# sex: f
# age: 57
# don't swap
# sex: m
# age: 71
# don't swap
# sex: f
# age: 84
# don't swap
# sex: f
# age: 76
# don't swap
# sex: m
# age: 85
# don't swap
# sex: f
# age: 4.24
# don't swap
# sex: m
# age: 43
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 54
# don't swap
# sex: m
# age: 70
# don't swap
# sex: m
# age: 75
# don't swap
# sex: f
# age: 32
# don't swap
# sex: m
# age: 59
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 8
# don't swap
# sex: m
# age: 37
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 79
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 35
# don't swap
# sex: m
# age: 52
# don't swap
# sex: m
# age: 37
# don't swap
# sex: m
# age: 57
# don't swap
# sex: f
# age: 39
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 58
# don't swap
# sex: 42
# age: m
# swap
# sex: f
# age: 69
# don't swap
# sex: m
# age: 16
# don't swap
# sex: f
# age: 73
# don't swap
# sex: m
# age: 7
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 71
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 67
# don't swap
# sex: f
# age: 48
# don't swap
# sex: 52
# age: m
# swap
# sex: m
# age: 47
# don't swap
# sex: f
# age: 52
# don't swap
# sex: m
# age: 84
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 38
# don't swap
# sex: m
# age: 29
# don't swap
# sex: 57
# age: f
# swap
# sex: m
# age: 74
# don't swap
# sex: 41
# age: f
# swap
# sex: m
# age: 66
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 16
# don't swap
# sex: m
# age: 3.72
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 56
# don't swap
# sex: 52
# age: f
# swap
# sex: m
# age: 27
# don't swap
# sex: f
# age: 41
# don't swap
# sex: f
# age: 19
# don't swap
# sex: 27
# age: m
# swap
# sex: 11
# age: f
# swap
# sex: m
# age: 71
# don't swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 50
# don't swap
# sex: f
# age: 37
# don't swap
# sex: m
# age: 8
# don't swap
# sex: 57
# age: m
# swap
# sex: f
# age: 66
# don't swap
# sex: m
# age: 8
# don't swap
# sex: m
# age: 49
# don't swap
# sex: m
# age: 18
# don't swap
# sex: m
# age: 32
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 46
# don't swap
# sex: m
# age: 38
# don't swap
# sex: f
# age: 32
# don't swap
# sex: m
# age: 37
# don't swap
# sex: 40
# age: f
# swap
# sex: f
# age: 56
# don't swap
# sex: 58
# age: f
# swap
# sex: f
# age: 14
# don't swap
# sex: m
# age: 24
# don't swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 41
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 46
# don't swap
# sex: 66
# age: m
# swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 62
# don't swap
# sex: 31
# age: f
# swap
# sex: m
# age: 47
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 83
# don't swap
# sex: 83
# age: m
# swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 78
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 58
# don't swap
# sex: m
# age: 41
# don't swap
# sex: m
# age: 44
# don't swap
# sex: m
# age: 71
# don't swap
# sex: f
# age: 6
# don't swap
# sex: 56
# age: m
# swap
# sex: 68
# age: f
# swap
# sex: f
# age: 18
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 38
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 48
# don't swap
# sex: f
# age: 11
# don't swap
# sex: f
# age: 51
# don't swap
# sex: m
# age: 56
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 22
# don't swap
# sex: f
# age: 36
# don't swap
# sex: m
# age: 54
# don't swap
# sex: f
# age: 25
# don't swap
# sex: 65
# age: m
# swap
# sex: f
# age: 8
# don't swap
# sex: f
# age: 17
# don't swap
# sex: m
# age: 8
# don't swap
# sex: m
# age: 68
# don't swap
# sex: f
# age: 37
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 55
# don't swap
# sex: 52
# age: f
# swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 23
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 51
# don't swap
# sex: m
# age: 80
# don't swap
# sex: 5
# age: f
# swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 53
# don't swap
# sex: m
# age: 57
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 17
# don't swap
# sex: f
# age: 51
# don't swap
# sex: 59
# age: f
# swap
# sex: f
# age: 6
# don't swap
# sex: f
# age: 57
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 27
# don't swap
# sex: 20
# age: f
# swap
# sex: m
# age: 68
# don't swap
# sex: m
# age: 24
# don't swap
# sex: 41
# age: f
# swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 12
# don't swap
# sex: m
# age: 55
# don't swap
# sex: m
# age: 84
# don't swap
# sex: f
# age: 49
# don't swap
# sex: m
# age: 33
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 31
# don't swap
# sex: m
# age: 28
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 67
# don't swap
# sex: f
# age: 71
# don't swap
# sex: 27
# age: m
# swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 29
# don't swap
# sex: 43
# age: f
# swap
# sex: f
# age: 14
# don't swap
# sex: m
# age: 84
# don't swap
# sex: m
# age: 64
# don't swap
# sex: m
# age: 74
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 4.24
# don't swap
# sex: f
# age: 75
# don't swap
# sex: f
# age: 73
# don't swap
# sex: f
# age: 78
# don't swap
# sex: m
# age: 15
# don't swap
# sex: f
# age: 24
# don't swap
# sex: m
# age: 44
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 3.72
# don't swap
# sex: m
# age: 32
# don't swap
# sex: m
# age: 47
# don't swap
# sex: m
# age: 24
# don't swap
# sex: m
# age: 79
# don't swap
# sex: m
# age: 4.16
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 32
# don't swap
# sex: m
# age: 47
# don't swap
# sex: 3.56
# age: f
# swap
# sex: m
# age: 70
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 26
# don't swap
# sex: f
# age: 58
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 58
# don't swap
# sex: m
# age: 39
# don't swap
# sex: f
# age: 52
# don't swap
# sex: 44
# age: f
# swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 61
# don't swap
# sex: m
# age: 20
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 44
# don't swap
# sex: m
# age: 64
# don't swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 78
# don't swap
# sex: 15
# age: m
# swap
# sex: m
# age: 10
# don't swap
# sex: m
# age: 50
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 66
# don't swap
# sex: m
# age: 3.48
# don't swap
# sex: f
# age: 83
# don't swap
# sex: m
# age: 82
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 32
# don't swap
# sex: 6
# age: m
# swap
# sex: f
# age: 48
# don't swap
# sex: m
# age: 3.48
# don't swap
# sex: f
# age: 35
# don't swap
# sex: m
# age: 59
# don't swap
# sex: m
# age: 70
# don't swap
# sex: f
# age: 51
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 22
# don't swap
# sex: f
# age: 39
# don't swap
# sex: f
# age: 67
# don't swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 57
# don't swap
# sex: 33
# age: f
# swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 11
# don't swap
# sex: m
# age: 40
# don't swap
# sex: m
# age: 29
# don't swap
# sex: m
# age: 37
# don't swap
# sex: f
# age: 76
# don't swap
# sex: m
# age: 16
# don't swap
# sex: m
# age: 22
# don't swap
# sex: m
# age: 36
# don't swap
# sex: f
# age: 46
# don't swap
# sex: f
# age: 76
# don't swap
# sex: f
# age: 4.72
# don't swap
# sex: m
# age: 83
# don't swap
# sex: m
# age: 58
# don't swap
# sex: m
# age: 12
# don't swap
# sex: 14
# age: m
# swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 20
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 6
# don't swap
# sex: f
# age: 70
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 12
# don't swap
# sex: m
# age: 11
# don't swap
# sex: m
# age: 43
# don't swap
# sex: 65
# age: f
# swap
# sex: f
# age: 33
# don't swap
# sex: m
# age: 51
# don't swap
# sex: 42
# age: f
# swap
# sex: 82
# age: f
# swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 41
# don't swap
# sex: 23
# age: m
# swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 14
# don't swap
# sex: m
# age: 49
# don't swap
# sex: m
# age: 74
# don't swap
# sex: m
# age: 56
# don't swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 79
# don't swap
# sex: f
# age: 76
# don't swap
# sex: m
# age: 10
# don't swap
# sex: f
# age: 57
# don't swap
# sex: m
# age: 84
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 27
# don't swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 80
# don't swap
# sex: m
# age: 11
# don't swap
# sex: m
# age: 84
# don't swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 73
# don't swap
# sex: m
# age: 54
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 50
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 64
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 44
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 39
# don't swap
# sex: f
# age: 78
# don't swap
# sex: m
# age: 40
# don't swap
# sex: m
# age: 52
# don't swap
# sex: m
# age: 19
# don't swap
# sex: f
# age: 37
# don't swap
# sex: f
# age: 30
# don't swap
# sex: m
# age: 3.48
# don't swap
# sex: m
# age: 10
# don't swap
# sex: m
# age: 10
# don't swap
# sex: m
# age: 15
# don't swap
# sex: m
# age: 44
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 15
# don't swap
# sex: f
# age: 37
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 52
# don't swap
# sex: m
# age: 85
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 67
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 84
# don't swap
# sex: m
# age: 65
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 54
# don't swap
# sex: m
# age: 58
# don't swap
# sex: m
# age: 65
# don't swap
# sex: m
# age: 30
# don't swap
# sex: m
# age: 67
# don't swap
# sex: f
# age: 55
# don't swap
# sex: m
# age: 8
# don't swap
# sex: m
# age: 14
# don't swap
# sex: m
# age: 57
# don't swap
# sex: f
# age: 23
# don't swap
# sex: m
# age: 33
# don't swap
# sex: f
# age: 45
# don't swap
# sex: 30
# age: m
# swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 21
# don't swap
# sex: f
# age: 66
# don't swap
# sex: m
# age: 75
# don't swap
# sex: m
# age: 22
# don't swap
# sex: f
# age: 4.32
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 12
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 27
# don't swap
# sex: m
# age: 25
# don't swap
# sex: m
# age: 32
# don't swap
# sex: m
# age: 16
# don't swap
# sex: 32
# age: m
# swap
# sex: f
# age: 58
# don't swap
# sex: m
# age: 85
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 49
# don't swap
# sex: m
# age: 3.8
# don't swap
# sex: f
# age: 11
# don't swap
# sex: m
# age: 49
# don't swap
# sex: m
# age: 78
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 35
# don't swap
# sex: m
# age: 76
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 3.64
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 22
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 11
# don't swap
# sex: f
# age: 19
# don't swap
# sex: 83
# age: f
# swap
# sex: m
# age: 20
# don't swap
# sex: 23
# age: f
# swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 21
# don't swap
# sex: f
# age: 39
# don't swap
# sex: m
# age: 64
# don't swap
# sex: f
# age: 56
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 50
# don't swap
# sex: m
# age: 44
# don't swap
# sex: 58
# age: f
# swap
# sex: f
# age: 44
# don't swap
# sex: m
# age: 64
# don't swap
# sex: f
# age: 10
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 33
# don't swap
# sex: m
# age: 34
# don't swap
# sex: 52
# age: f
# swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 36
# don't swap
# sex: m
# age: 67
# don't swap
# sex: f
# age: 5
# don't swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 15
# don't swap
# sex: f
# age: 43
# don't swap
# sex: m
# age: 80
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 22
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 66
# don't swap
# sex: m
# age: 47
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 48
# don't swap
# sex: m
# age: 52
# don't swap
# sex: f
# age: 3.56
# don't swap
# sex: m
# age: 15
# don't swap
# sex: m
# age: 12
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 41
# don't swap
# sex: m
# age: 15
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 57
# don't swap
# sex: 62
# age: f
# swap
# sex: m
# age: 84
# don't swap
# sex: f
# age: 36
# don't swap
# sex: m
# age: 79
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 79
# don't swap
# sex: f
# age: 58
# don't swap
# sex: 69
# age: f
# swap
# sex: m
# age: 54
# don't swap
# sex: m
# age: 74
# don't swap
# sex: f
# age: 16
# don't swap
# sex: m
# age: 44
# don't swap
# sex: f
# age: 58
# don't swap
# sex: m
# age: 30
# don't swap
# sex: f
# age: 13
# don't swap
# sex: m
# age: 41
# don't swap
# sex: f
# age: 82
# don't swap
# sex: m
# age: 8
# don't swap
# sex: m
# age: 26
# don't swap
# sex: m
# age: 22
# don't swap
# sex: m
# age: 54
# don't swap
# sex: m
# age: 49
# don't swap
# sex: m
# age: 43
# don't swap
# sex: f
# age: 58
# don't swap
# sex: m
# age: 74
# don't swap
# sex: m
# age: 75
# don't swap
# sex: m
# age: 7
# don't swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 25
# don't swap
# sex: m
# age: 27
# don't swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 73
# don't swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 85
# don't swap
# sex: m
# age: 12
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 58
# don't swap
# sex: 55
# age: f
# swap
# sex: f
# age: 23
# don't swap
# sex: f
# age: 4.48
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 46
# don't swap
# sex: f
# age: 23
# don't swap
# sex: m
# age: 26
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 3.72
# don't swap
# sex: m
# age: 74
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 8
# don't swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 6
# don't swap
# sex: f
# age: 20
# don't swap
# sex: f
# age: 3.88
# don't swap
# sex: m
# age: 47
# don't swap
# sex: 73
# age: f
# swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 33
# don't swap
# sex: f
# age: 34
# don't swap
# sex: m
# age: 66
# don't swap
# sex: m
# age: 28
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 67
# don't swap
# sex: m
# age: 67
# don't swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 16
# don't swap
# sex: m
# age: 51
# don't swap
# sex: f
# age: 8
# don't swap
# sex: f
# age: 57
# don't swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 64
# don't swap
# sex: f
# age: 52
# don't swap
# sex: m
# age: 22
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 25
# don't swap
# sex: m
# age: 47
# don't swap
# sex: m
# age: 70
# don't swap
# sex: m
# age: 75
# don't swap
# sex: m
# age: 6
# don't swap
# sex: m
# age: 16
# don't swap
# sex: m
# age: 6
# don't swap
# sex: f
# age: 32
# don't swap
# sex: m
# age: 42
# don't swap
# sex: 22
# age: f
# swap
# sex: f
# age: 48
# don't swap
# sex: m
# age: 80
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 42
# don't swap
# sex: f
# age: 34
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 74
# don't swap
# sex: f
# age: 21
# don't swap
# sex: m
# age: 75
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 8
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 21
# don't swap
# sex: f
# age: 44
# don't swap
# sex: m
# age: 54
# don't swap
# sex: m
# age: 3.72
# don't swap
# sex: f
# age: 70
# don't swap
# sex: m
# age: 78
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 59
# don't swap
# sex: m
# age: 15
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 11
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 40
# don't swap
# sex: f
# age: 46
# don't swap
# sex: m
# age: 20
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 32
# don't swap
# sex: m
# age: 65
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 26
# don't swap
# sex: m
# age: 66
# don't swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 40
# don't swap
# sex: m
# age: 29
# don't swap
# sex: f
# age: 14
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 76
# don't swap
# sex: f
# age: 84
# don't swap
# sex: 19
# age: f
# swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 39
# don't swap
# sex: m
# age: 33
# don't swap
# sex: f
# age: 85
# don't swap
# sex: m
# age: 64
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 43
# don't swap
# sex: m
# age: 57
# don't swap
# sex: f
# age: 70
# don't swap
# sex: m
# age: 55
# don't swap
# sex: f
# age: 41
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 21
# don't swap
# sex: f
# age: 71
# don't swap
# sex: m
# age: 51
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 60
# don't swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 41
# don't swap
# sex: 6
# age: f
# swap
# sex: 54
# age: f
# swap
# sex: f
# age: 63
# don't swap
# sex: 80
# age: f
# swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 54
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 80
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 73
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 73
# don't swap
# sex: f
# age: 15
# don't swap
# sex: m
# age: 46
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 54
# don't swap
# sex: m
# age: 42
# don't swap
# sex: m
# age: 15
# don't swap
# sex: m
# age: 34
# don't swap
# sex: m
# age: 25
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 85
# don't swap
# sex: f
# age: 46
# don't swap
# sex: f
# age: 41
# don't swap
# sex: m
# age: 54
# don't swap
# sex: m
# age: 40
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 40
# don't swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 53
# don't swap
# sex: m
# age: 50
# don't swap
# sex: f
# age: 38
# don't swap
# sex: f
# age: 58
# don't swap
# sex: f
# age: 43
# don't swap
# sex: f
# age: 59
# don't swap
# sex: m
# age: 10
# don't swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 31
# don't swap
# sex: m
# age: 83
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 4.72
# don't swap
# sex: f
# age: 79
# don't swap
# sex: f
# age: 57
# don't swap
# sex: 81
# age: f
# swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 64
# don't swap
# sex: f
# age: 85
# don't swap
# sex: m
# age: 19
# don't swap
# sex: f
# age: 5
# don't swap
# sex: m
# age: 75
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 37
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 82
# don't swap
# sex: m
# age: 29
# don't swap
# sex: m
# age: 67
# don't swap
# sex: f
# age: 3.56
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 34
# don't swap
# sex: f
# age: 22
# don't swap
# sex: f
# age: 16
# don't swap
# sex: 9
# age: f
# swap
# sex: f
# age: 57
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 85
# don't swap
# sex: m
# age: 26
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 60
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 19
# don't swap
# sex: f
# age: 85
# don't swap
# sex: m
# age: 63
# don't swap
# sex: m
# age: 30
# don't swap
# sex: f
# age: 23
# don't swap
# sex: f
# age: 53
# don't swap
# sex: m
# age: 46
# don't swap
# sex: m
# age: 18
# don't swap
# sex: m
# age: 78
# don't swap
# sex: m
# age: 20
# don't swap
# sex: m
# age: 38
# don't swap
# sex: m
# age: 74
# don't swap
# sex: m
# age: 4.4
# don't swap
# sex: f
# age: 57
# don't swap
# sex: m
# age: 78
# don't swap
# sex: f
# age: 85
# don't swap
# sex: m
# age: 13
# don't swap
# sex: 27
# age: f
# swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 29
# don't swap
# sex: m
# age: 75
# don't swap
# sex: 5
# age: f
# swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 37
# don't swap
# sex: m
# age: 12
# don't swap
# sex: f
# age: 5
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 8
# don't swap
# sex: f
# age: 27
# don't swap
# sex: m
# age: 60
# don't swap
# sex: f
# age: 26
# don't swap
# sex: 23
# age: m
# swap
# sex: f
# age: 66
# don't swap
# sex: 40
# age: f
# swap
# sex: m
# age: 42
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 67
# don't swap
# sex: m
# age: 25
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 6
# don't swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 50
# don't swap
# sex: 85
# age: f
# swap
# sex: m
# age: 27
# don't swap
# sex: f
# age: 37
# don't swap
# sex: m
# age: 4.4
# don't swap
# sex: 69
# age: f
# swap
# sex: m
# age: 84
# don't swap
# sex: m
# age: 18
# don't swap
# sex: f
# age: 12
# don't swap
# sex: f
# age: 11
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 36
# don't swap
# sex: 36
# age: f
# swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 70
# don't swap
# sex: m
# age: 78
# don't swap
# sex: f
# age: 70
# don't swap
# sex: m
# age: 28
# don't swap
# sex: m
# age: 31
# don't swap
# sex: f
# age: 11
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 34
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 68
# don't swap
# sex: m
# age: 77
# don't swap
# sex: f
# age: 44
# don't swap
# sex: m
# age: 37
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 83
# don't swap
# sex: f
# age: 74
# don't swap
# sex: m
# age: 12
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 11
# don't swap
# sex: f
# age: 61
# don't swap
# sex: m
# age: 7
# don't swap
# sex: m
# age: 54
# don't swap
# sex: 64
# age: m
# swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 67
# don't swap
# sex: m
# age: 83
# don't swap
# sex: m
# age: 11
# don't swap
# sex: m
# age: 17
# don't swap
# sex: m
# age: 55
# don't swap
# sex: f
# age: 49
# don't swap
# sex: m
# age: 58
# don't swap
# sex: 60
# age: m
# swap
# sex: f
# age: 54
# don't swap
# sex: m
# age: 14
# don't swap
# sex: f
# age: 65
# don't swap
# sex: m
# age: 3.32
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 53
# don't swap
# sex: m
# age: 16
# don't swap
# sex: m
# age: 55
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 85
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 44
# don't swap
# sex: f
# age: 22
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 78
# don't swap
# sex: m
# age: 80
# don't swap
# sex: m
# age: 75
# don't swap
# sex: 71
# age: f
# swap
# sex: m
# age: 26
# don't swap
# sex: m
# age: 46
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 64
# don't swap
# sex: f
# age: 38
# don't swap
# sex: f
# age: 25
# don't swap
# sex: 78
# age: f
# swap
# sex: m
# age: 67
# don't swap
# sex: f
# age: 46
# don't swap
# sex: f
# age: 46
# don't swap
# sex: m
# age: 77
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 66
# don't swap
# sex: m
# age: 57
# don't swap
# sex: m
# age: 41
# don't swap
# sex: m
# age: 71
# don't swap
# sex: f
# age: 57
# don't swap
# sex: m
# age: 80
# don't swap
# sex: 22
# age: f
# swap
# sex: m
# age: 51
# don't swap
# sex: 40
# age: m
# swap
# sex: f
# age: 20
# don't swap
# sex: f
# age: 67
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 9
# don't swap
# sex: f
# age: 48
# don't swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 74
# don't swap
# sex: f
# age: 41
# don't swap
# sex: f
# age: 16
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 11
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 32
# don't swap
# sex: 13
# age: m
# swap
# sex: f
# age: 41
# don't swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 39
# don't swap
# sex: m
# age: 69
# don't swap
# sex: f
# age: 42
# don't swap
# sex: f
# age: 9
# don't swap
# sex: f
# age: 67
# don't swap
# sex: f
# age: 69
# don't swap
# sex: 39
# age: m
# swap
# sex: m
# age: 48
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 70
# don't swap
# sex: m
# age: 3.08
# don't swap
# sex: m
# age: 51
# don't swap
# sex: m
# age: 34
# don't swap
# sex: f
# age: 62
# don't swap
# sex: 45
# age: f
# swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 69
# don't swap
# sex: m
# age: 77
# don't swap
# sex: f
# age: 35
# don't swap
# sex: m
# age: 10
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 20
# don't swap
# sex: f
# age: 58
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 58
# don't swap
# sex: 68
# age: f
# swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 76
# don't swap
# sex: m
# age: 10
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 5
# don't swap
# sex: 4.56
# age: m
# swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 39
# don't swap
# sex: m
# age: 22
# don't swap
# sex: f
# age: 17
# don't swap
# sex: m
# age: 8
# don't swap
# sex: m
# age: 75
# don't swap
# sex: m
# age: 59
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 12
# don't swap
# sex: 46
# age: f
# swap
# sex: f
# age: 29
# don't swap
# sex: 54
# age: f
# swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 42
# don't swap
# sex: f
# age: 71
# don't swap
# sex: f
# age: 70
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 76
# don't swap
# sex: m
# age: 83
# don't swap
# sex: f
# age: 11
# don't swap
# sex: f
# age: 12
# don't swap
# sex: f
# age: 28
# don't swap
# sex: 71
# age: f
# swap
# sex: m
# age: 27
# don't swap
# sex: m
# age: 37
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 81
# don't swap
# sex: 75
# age: f
# swap
# sex: m
# age: 3.48
# don't swap
# sex: f
# age: 49
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 56
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 4.32
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 30
# don't swap
# sex: 54
# age: f
# swap
# sex: m
# age: 51
# don't swap
# sex: f
# age: 21
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 10
# don't swap
# sex: m
# age: 11
# don't swap
# sex: m
# age: 52
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 35
# don't swap
# sex: f
# age: 55
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 61
# don't swap
# sex: 51
# age: f
# swap
# sex: m
# age: 58
# don't swap
# sex: m
# age: 21
# don't swap
# sex: m
# age: 34
# don't swap
# sex: f
# age: 8
# don't swap
# sex: f
# age: 57
# don't swap
# sex: f
# age: 49
# don't swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 57
# don't swap
# sex: 15
# age: m
# swap
# sex: f
# age: 11
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 60
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 68
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 16
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 18
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 3.8
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 21
# don't swap
# sex: m
# age: 77
# don't swap
# sex: m
# age: 65
# don't swap
# sex: f
# age: 83
# don't swap
# sex: m
# age: 67
# don't swap
# sex: m
# age: 54
# don't swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 5
# don't swap
# sex: m
# age: 4.56
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 15
# don't swap
# sex: m
# age: 73
# don't swap
# sex: m
# age: 11
# don't swap
# sex: f
# age: 55
# don't swap
# sex: m
# age: 34
# don't swap
# sex: m
# age: 22
# don't swap
# sex: 17
# age: f
# swap
# sex: m
# age: 16
# don't swap
# sex: m
# age: 79
# don't swap
# sex: f
# age: 30
# don't swap
# sex: m
# age: 70
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 59
# don't swap
# sex: m
# age: 46
# don't swap
# sex: 19
# age: f
# swap
# sex: 61
# age: f
# swap
# sex: m
# age: 67
# don't swap
# sex: 7
# age: f
# swap
# sex: f
# age: 51
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 45
# don't swap
# sex: 10
# age: f
# swap
# sex: m
# age: 55
# don't swap
# sex: m
# age: 42
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 72
# don't swap
# sex: m
# age: 67
# don't swap
# sex: m
# age: 23
# don't swap
# sex: m
# age: 34
# don't swap
# sex: m
# age: 54
# don't swap
# sex: f
# age: 6
# don't swap
# sex: m
# age: 16
# don't swap
# sex: m
# age: 55
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 31
# don't swap
# sex: m
# age: 82
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 24
# don't swap
# sex: m
# age: 10
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 75
# don't swap
# sex: m
# age: 36
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 14
# don't swap
# sex: m
# age: 74
# don't swap
# sex: 25
# age: f
# swap
# sex: m
# age: 26
# don't swap
# sex: m
# age: 9
# don't swap
# sex: f
# age: 18
# don't swap
# sex: m
# age: 73
# don't swap
# sex: m
# age: 24
# don't swap
# sex: m
# age: 47
# don't swap
# sex: f
# age: 67
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 24
# don't swap
# sex: m
# age: 21
# don't swap
# sex: f
# age: 36
# don't swap
# sex: m
# age: 49
# don't swap
# sex: m
# age: 37
# don't swap
# sex: 60
# age: m
# swap
# sex: m
# age: 9
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 78
# don't swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 65
# don't swap
# sex: 65
# age: m
# swap
# sex: m
# age: 79
# don't swap
# sex: m
# age: 78
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 54
# don't swap
# sex: m
# age: 58
# don't swap
# sex: m
# age: 71
# don't swap
# sex: m
# age: 46
# don't swap
# sex: f
# age: 19
# don't swap
# sex: m
# age: 84
# don't swap
# sex: f
# age: 77
# don't swap
# sex: 82
# age: f
# swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 70
# don't swap
# sex: f
# age: 56
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 36
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 15
# don't swap
# sex: f
# age: 64
# don't swap
# sex: m
# age: 47
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 10
# don't swap
# sex: m
# age: 43
# don't swap
# sex: f
# age: 39
# don't swap
# sex: f
# age: 3.16
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 54
# don't swap
# sex: m
# age: 27
# don't swap
# sex: m
# age: 3.8
# don't swap
# sex: m
# age: 32
# don't swap
# sex: f
# age: 84
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 17
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 41
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 32
# don't swap
# sex: m
# age: 22
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 74
# don't swap
# sex: m
# age: 74
# don't swap
# sex: m
# age: 42
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 53
# don't swap
# sex: m
# age: 9
# don't swap
# sex: m
# age: 26
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 49
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 71
# don't swap
# sex: 65
# age: m
# swap
# sex: f
# age: 53
# don't swap
# sex: m
# age: 85
# don't swap
# sex: f
# age: 57
# don't swap
# sex: m
# age: 24
# don't swap
# sex: m
# age: 45
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 68
# don't swap
# sex: f
# age: 25
# don't swap
# sex: m
# age: 73
# don't swap
# sex: m
# age: 33
# don't swap
# sex: m
# age: 68
# don't swap
# sex: f
# age: 3.08
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 21
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 30
# don't swap
# sex: m
# age: 9
# don't swap
# sex: f
# age: 17
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 77
# don't swap
# sex: f
# age: 59
# don't swap
# sex: m
# age: 80
# don't swap
# sex: 55
# age: m
# swap
# sex: f
# age: 6
# don't swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 83
# don't swap
# sex: m
# age: 57
# don't swap
# sex: f
# age: 40
# don't swap
# sex: m
# age: 44
# don't swap
# sex: m
# age: 18
# don't swap
# sex: m
# age: 13
# don't swap
# sex: m
# age: 41
# don't swap
# sex: f
# age: 77
# don't swap
# sex: f
# age: 9
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 73
# don't swap
# sex: m
# age: 55
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 77
# don't swap
# sex: m
# age: 64
# don't swap
# sex: f
# age: 84
# don't swap
# sex: m
# age: 11
# don't swap
# sex: m
# age: 24
# don't swap
# sex: m
# age: 50
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 24
# don't swap
# sex: m
# age: 17
# don't swap
# sex: m
# age: 57
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 77
# don't swap
# sex: f
# age: 42
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 82
# don't swap
# sex: m
# age: 51
# don't swap
# sex: f
# age: 52
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 52
# don't swap
# sex: m
# age: 36
# don't swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 59
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 25
# don't swap
# sex: m
# age: 60
# don't swap
# sex: m
# age: 3.56
# don't swap
# sex: 36
# age: f
# swap
# sex: f
# age: 40
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 73
# don't swap
# sex: f
# age: 24
# don't swap
# sex: m
# age: 66
# don't swap
# sex: m
# age: 69
# don't swap
# sex: f
# age: 71
# don't swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 40
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 73
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 49
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 8
# don't swap
# sex: f
# age: 74
# don't swap
# sex: f
# age: 15
# don't swap
# sex: f
# age: 73
# don't swap
# sex: 64
# age: f
# swap
# sex: f
# age: 6
# don't swap
# sex: m
# age: 61
# don't swap
# sex: m
# age: 36
# don't swap
# sex: m
# age: 20
# don't swap
# sex: 83
# age: f
# swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 20
# don't swap
# sex: 44
# age: m
# swap
# sex: m
# age: 23
# don't swap
# sex: f
# age: 81
# don't swap
# sex: 44
# age: f
# swap
# sex: m
# age: 15
# don't swap
# sex: m
# age: 57
# don't swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 3.64
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 23
# don't swap
# sex: f
# age: 39
# don't swap
# sex: f
# age: 76
# don't swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 17
# don't swap
# sex: f
# age: 32
# don't swap
# sex: 62
# age: f
# swap
# sex: m
# age: 47
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 49
# don't swap
# sex: m
# age: 38
# don't swap
# sex: m
# age: 4.8
# don't swap
# sex: f
# age: 8
# don't swap
# sex: 46
# age: f
# swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 11
# don't swap
# sex: f
# age: 32
# don't swap
# sex: m
# age: 9
# don't swap
# sex: f
# age: 37
# don't swap
# sex: m
# age: 69
# don't swap
# sex: f
# age: 78
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 75
# don't swap
# sex: m
# age: 34
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 65
# don't swap
# sex: f
# age: 79
# don't swap
# sex: m
# age: 31
# don't swap
# sex: 46
# age: m
# swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 75
# don't swap
# sex: f
# age: 64
# don't swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 68
# don't swap
# sex: f
# age: 12
# don't swap
# sex: m
# age: 47
# don't swap
# sex: f
# age: 40
# don't swap
# sex: m
# age: 21
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 79
# don't swap
# sex: f
# age: 72
# don't swap
# sex: m
# age: 54
# don't swap
# sex: f
# age: 16
# don't swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 70
# don't swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 37
# don't swap
# sex: f
# age: 83
# don't swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 59
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 12
# don't swap
# sex: m
# age: 64
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 41
# don't swap
# sex: m
# age: 36
# don't swap
# sex: m
# age: 68
# don't swap
# sex: f
# age: 16
# don't swap
# sex: m
# age: 23
# don't swap
# sex: m
# age: 54
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 44
# don't swap
# sex: m
# age: 31
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 33
# don't swap
# sex: m
# age: 58
# don't swap
# sex: m
# age: 75
# don't swap
# sex: f
# age: 37
# don't swap
# sex: f
# age: 23
# don't swap
# sex: m
# age: 34
# don't swap
# sex: f
# age: 71
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 65
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 4.56
# don't swap
# sex: f
# age: 61
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 21
# don't swap
# sex: 58
# age: m
# swap
# sex: f
# age: 5
# don't swap
# sex: f
# age: 70
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 18
# don't swap
# sex: f
# age: 73
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 11
# don't swap
# sex: m
# age: 17
# don't swap
# sex: m
# age: 67
# don't swap
# sex: m
# age: 35
# don't swap
# sex: m
# age: 58
# don't swap
# sex: 59
# age: m
# swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 58
# don't swap
# sex: m
# age: 50
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 72
# don't swap
# sex: m
# age: 76
# don't swap
# sex: m
# age: 61
# ...
# age: 54
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 35
# don't swap
# sex: f
# age: 57
# don't swap
# sex: f
# age: 25
# don't swap
# sex: m
# age: 8
# don't swap
# sex: m
# age: 18
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 28
# don't swap
# sex: f
# age: 46
# don't swap
# sex: m
# age: 39
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 40
# don't swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 78
# don't swap
# sex: 55
# age: m
# swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 71
# don't swap
# sex: m
# age: 67
# don't swap
# sex: f
# age: 66
# don't swap
# sex: m
# age: 55
# don't swap
# sex: m
# age: 66
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 82
# don't swap
# sex: f
# age: 85
# don't swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 76
# don't swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 57
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 29
# don't swap
# sex: 63
# age: f
# swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 14
# don't swap
# sex: 28
# age: f
# swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 17
# don't swap
# sex: 21
# age: f
# swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 4.32
# don't swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 59
# don't swap
# sex: m
# age: 51
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 69
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 57
# don't swap
# sex: m
# age: 25
# don't swap
# sex: m
# age: 40
# don't swap
# sex: m
# age: 77
# don't swap
# sex: 22
# age: m
# swap
# sex: m
# age: 24
# don't swap
# sex: f
# age: 75
# don't swap
# sex: m
# age: 66
# don't swap
# sex: m
# age: 27
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 39
# don't swap
# sex: f
# age: 65
# don't swap
# sex: f
# age: 30
# don't swap
# sex: 68
# age: m
# swap
# sex: f
# age: 64
# don't swap
# sex: m
# age: 20
# don't swap
# sex: m
# age: 77
# don't swap
# sex: f
# age: 32
# don't swap
# sex: f
# age: 59
# don't swap
# sex: m
# age: 74
# don't swap
# sex: f
# age: 27
# don't swap
# sex: m
# age: 9
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 27
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 74
# don't swap
# sex: m
# age: 22
# don't swap
# sex: f
# age: 31
# don't swap
# sex: m
# age: 42
# don't swap
# sex: f
# age: 3.32
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 7
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 70
# don't swap
# sex: m
# age: 4.88
# don't swap
# sex: f
# age: 56
# don't swap
# sex: f
# age: 82
# don't swap
# sex: m
# age: 45
# don't swap
# sex: m
# age: 35
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 3.64
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 16
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 48
# don't swap
# sex: 43
# age: m
# swap
# sex: f
# age: 3.72
# don't swap
# sex: m
# age: 49
# don't swap
# sex: m
# age: 27
# don't swap
# sex: f
# age: 58
# don't swap
# sex: m
# age: 36
# don't swap
# sex: 18
# age: f
# swap
# sex: m
# age: 58
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 75
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 81
# don't swap
# sex: f
# age: 20
# don't swap
# sex: m
# age: 83
# don't swap
# sex: m
# age: 7
# don't swap
# sex: f
# age: 15
# don't swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 16
# don't swap
# sex: f
# age: 20
# don't swap
# sex: f
# age: 70
# don't swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 46
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 65
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 70
# don't swap
# sex: m
# age: 26
# don't swap
# sex: f
# age: 9
# don't swap
# sex: f
# age: 46
# don't swap
# sex: m
# age: 85
# don't swap
# sex: 56
# age: f
# swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 50
# don't swap
# sex: 50
# age: m
# swap
# sex: f
# age: 19
# don't swap
# sex: f
# age: 12
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 74
# don't swap
# sex: m
# age: 73
# don't swap
# sex: f
# age: 41
# don't swap
# sex: m
# age: 5
# don't swap
# sex: f
# age: 45
# don't swap
# sex: 71
# age: f
# swap
# sex: f
# age: 37
# don't swap
# sex: m
# age: 26
# don't swap
# sex: m
# age: 28
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 51
# don't swap
# sex: f
# age: 74
# don't swap
# sex: f
# age: 49
# don't swap
# sex: f
# age: 8
# don't swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 84
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 23
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 83
# don't swap
# sex: f
# age: 51
# don't swap
# sex: m
# age: 63
# don't swap
# sex: m
# age: 75
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 37
# don't swap
# sex: m
# age: 50
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 29
# don't swap
# sex: m
# age: 14
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 6
# don't swap
# sex: f
# age: 21
# don't swap
# sex: f
# age: 52
# don't swap
# sex: m
# age: 44
# don't swap
# sex: m
# age: 10
# don't swap
# sex: f
# age: 57
# don't swap
# sex: f
# age: 37
# don't swap
# sex: f
# age: 21
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 23
# don't swap
# sex: f
# age: 62
# don't swap
# sex: f
# age: 83
# don't swap
# sex: m
# age: 12
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 65
# don't swap
# sex: 85
# age: f
# swap
# sex: m
# age: 23
# don't swap
# sex: m
# age: 64
# don't swap
# sex: m
# age: 41
# don't swap
# sex: m
# age: 47
# don't swap
# sex: 72
# age: m
# swap
# sex: m
# age: 73
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 60
# don't swap
# sex: m
# age: 12
# don't swap
# sex: f
# age: 61
# don't swap
# sex: m
# age: 21
# don't swap
# sex: m
# age: 62
# don't swap
# sex: m
# age: 35
# don't swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 79
# don't swap
# sex: m
# age: 70
# don't swap
# sex: m
# age: 14
# don't swap
# sex: m
# age: 16
# don't swap
# sex: 80
# age: f
# swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 71
# don't swap
# sex: f
# age: 34
# don't swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 69
# don't swap
# sex: m
# age: 55
# don't swap
# sex: m
# age: 35
# don't swap
# sex: f
# age: 83
# don't swap
# sex: f
# age: 56
# don't swap
# sex: 24
# age: f
# swap
# sex: f
# age: 13
# don't swap
# sex: f
# age: 84
# don't swap
# sex: f
# age: 60
# don't swap
# sex: f
# age: 80
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 31
# don't swap
# sex: 42
# age: f
# swap
# sex: m
# age: 83
# don't swap
# sex: m
# age: 69
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 71
# don't swap
# sex: f
# age: 18
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 54
# don't swap
# sex: m
# age: 59
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 68
# don't swap
# sex: m
# age: 24
# don't swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 3.72
# don't swap
# sex: f
# age: 35
# don't swap
# sex: m
# age: 42
# don't swap
# sex: f
# age: 74
# don't swap
# sex: m
# age: 46
# don't swap
# sex: m
# age: 33
# don't swap
# sex: m
# age: 33
# don't swap
# sex: f
# age: 22
# don't swap
# sex: m
# age: 31
# don't swap
# sex: m
# age: 57
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 3.56
# don't swap
# sex: f
# age: 24
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 64
# don't swap
# sex: m
# age: 4.16
# don't swap
# sex: 22
# age: f
# swap
# sex: m
# age: 39
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 38
# don't swap
# sex: 85
# age: m
# swap
# sex: m
# age: 3.64
# don't swap
# sex: f
# age: 20
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 61
# don't swap
# sex: m
# age: 7
# don't swap
# sex: m
# age: 83
# don't swap
# sex: m
# age: 36
# don't swap
# sex: m
# age: 84
# don't swap
# sex: m
# age: 28
# don't swap
# sex: f
# age: 38
# don't swap
# sex: m
# age: 46
# don't swap
# sex: f
# age: 50
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 43
# don't swap
# sex: 55
# age: f
# swap
# sex: f
# age: 84
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 43
# don't swap
# sex: m
# age: 72
# don't swap
# sex: f
# age: 65
# don't swap
# sex: 21
# age: f
# swap
# sex: m
# age: 11
# don't swap
# sex: 14
# age: m
# swap
# sex: m
# age: 75
# don't swap
# sex: f
# age: 53
# don't swap
# sex: m
# age: 69
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 11
# don't swap
# sex: f
# age: 73
# don't swap
# sex: f
# age: 6
# don't swap
# sex: m
# age: 47
# don't swap
# sex: m
# age: 26
# don't swap
# sex: f
# age: 46
# don't swap
# sex: 10
# age: f
# swap
# sex: f
# age: 67
# don't swap
# sex: m
# age: 7
# don't swap
# sex: f
# age: 80
# don't swap
# sex: f
# age: 20
# don't swap
# sex: f
# age: 15
# don't swap
# sex: 17
# age: f
# swap
# sex: f
# age: 23
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 46
# don't swap
# sex: f
# age: 37
# don't swap
# sex: f
# age: 42
# don't swap
# sex: m
# age: 49
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 6
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 57
# don't swap
# sex: 44
# age: f
# swap
# sex: m
# age: 45
# don't swap
# sex: m
# age: 36
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 72
# don't swap
# sex: m
# age: 82
# don't swap
# sex: m
# age: 83
# don't swap
# sex: m
# age: 4.08
# don't swap
# sex: f
# age: 68
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 38
# don't swap
# sex: m
# age: 6
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 65
# don't swap
# sex: f
# age: 73
# don't swap
# sex: f
# age: 64
# don't swap
# sex: m
# age: 12
# don't swap
# sex: f
# age: 9
# don't swap
# sex: m
# age: 24
# don't swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 33
# don't swap
# sex: m
# age: 42
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 48
# don't swap
# sex: m
# age: 64
# don't swap
# sex: 23
# age: f
# swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 39
# don't swap
# sex: f
# age: 83
# don't swap
# sex: f
# age: 48
# don't swap
# sex: 84
# age: m
# swap
# sex: m
# age: 35
# don't swap
# sex: f
# age: 27
# don't swap
# sex: f
# age: 5
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 19
# don't swap
# sex: m
# age: 62
# don't swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 26
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 29
# don't swap
# sex: f
# age: 81
# don't swap
# sex: 85
# age: m
# swap
# sex: f
# age: 68
# don't swap
# sex: f
# age: 11
# don't swap
# sex: f
# age: 64
# don't swap
# sex: f
# age: 39
# don't swap
# sex: m
# age: 4.56
# don't swap
# sex: m
# age: 82
# don't swap
# sex: f
# age: 79
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 33
# don't swap
# sex: f
# age: 76
# don't swap
# sex: m
# age: 44
# don't swap
# sex: m
# age: 48
# don't swap
# sex: m
# age: 55
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 81
# don't swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 42
# don't swap
# sex: f
# age: 57
# don't swap
# sex: m
# age: 61
# don't swap
# sex: f
# age: 52
# don't swap
# sex: f
# age: 35
# don't swap
# sex: m
# age: 13
# don't swap
# sex: f
# age: 48
# don't swap
# sex: f
# age: 41
# don't swap
# sex: f
# age: 48
# don't swap
# sex: 44
# age: m
# swap
# sex: f
# age: 3.88
# don't swap
# sex: m
# age: 13
# don't swap
# sex: 70
# age: f
# swap
# sex: 50
# age: f
# swap
# sex: m
# age: 7
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 67
# don't swap
# sex: f
# age: 10
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 17
# don't swap
# sex: f
# age: 68
# don't swap
# sex: 48
# age: f
# swap
# sex: m
# age: 82
# don't swap
# sex: m
# age: 71
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 56
# don't swap
# sex: m
# age: 5
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 75
# don't swap
# sex: f
# age: 61
# don't swap
# sex: m
# age: 37
# don't swap
# sex: m
# age: 54
# don't swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 69
# don't swap
# sex: 67
# age: m
# swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 43
# don't swap
# sex: f
# age: 8
# don't swap
# sex: f
# age: 3.4
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 23
# don't swap
# sex: 39
# age: m
# swap
# sex: f
# age: 47
# don't swap
# sex: 43
# age: f
# swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 59
# don't swap
# sex: m
# age: 35
# don't swap
# sex: f
# age: 5
# don't swap
# sex: m
# age: 78
# don't swap
# sex: f
# age: 57
# don't swap
# sex: f
# age: 51
# don't swap
# sex: 56
# age: f
# swap
# sex: 12
# age: m
# swap
# sex: f
# age: 42
# don't swap
# sex: f
# age: 20
# don't swap
# sex: m
# age: 42
# don't swap
# sex: m
# age: 32
# don't swap
# sex: f
# age: 68
# don't swap
# sex: f
# age: 61
# don't swap
# sex: m
# age: 15
# don't swap
# sex: f
# age: 15
# don't swap
# sex: f
# age: 58
# don't swap
# sex: 32
# age: m
# swap
# sex: m
# age: 62
# don't swap
# sex: m
# age: 38
# don't swap
# sex: f
# age: 82
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 58
# don't swap
# sex: f
# age: 34
# don't swap
# sex: f
# age: 34
# don't swap
# sex: f
# age: 84
# don't swap
# sex: 15
# age: m
# swap
# sex: f
# age: 47
# don't swap
# sex: f
# age: 24
# don't swap
# sex: m
# age: 41
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 27
# don't swap
# sex: m
# age: 36
# don't swap
# sex: f
# age: 30
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 49
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 36
# don't swap
# sex: f
# age: 83
# don't swap
# sex: m
# age: 73
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 60
# don't swap
# sex: f
# age: 5
# don't swap
# sex: f
# age: 23
# don't swap
# sex: f
# age: 63
# don't swap
# sex: f
# age: 50
# don't swap
# sex: m
# age: 21
# don't swap
# sex: f
# age: 81
# don't swap
# sex: m
# age: 63
# don't swap
# sex: 8
# age: m
# swap
# sex: 55
# age: m
# swap
# sex: m
# age: 43
# don't swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 17
# don't swap
# sex: f
# age: 79
# don't swap
# sex: f
# age: 34
# don't swap
# sex: f
# age: 64
# don't swap
# sex: m
# age: 58
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 59
# don't swap
# sex: f
# age: 70
# don't swap
# sex: 11
# age: f
# swap
# sex: f
# age: 47
# don't swap
# sex: m
# age: 8
# don't swap
# sex: f
# age: 31
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 63
# don't swap
# sex: f
# age: 65
# don't swap
# sex: m
# age: 47
# don't swap
# sex: m
# age: 65
# don't swap
# sex: f
# age: 80
# don't swap
# sex: f
# age: 10
# don't swap
# sex: m
# age: 25
# don't swap
# sex: f
# age: 13
# don't swap
# sex: m
# age: 22
# don't swap
# sex: m
# age: 17
# don't swap
# sex: m
# age: 59
# don't swap
# sex: f
# age: 44
# don't swap
# sex: f
# age: 18
# don't swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 45
# don't swap
# sex: f
# age: 22
# don't swap
# sex: m
# age: 65
# don't swap
# sex: m
# age: 83
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 43
# don't swap
# sex: 39
# age: f
# swap
# sex: f
# age: 5
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 30
# don't swap
# sex: f
# age: 34
# don't swap
# sex: m
# age: 11
# don't swap
# sex: f
# age: 37
# don't swap
# sex: f
# age: 23
# don't swap
# sex: f
# age: 14
# don't swap
# sex: m
# age: 11
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 55
# don't swap
# sex: f
# age: 4.4
# don't swap
# sex: f
# age: 67
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 28
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 69
# don't swap
# sex: f
# age: 63
# don't swap
# sex: m
# age: 66
# don't swap
# sex: m
# age: 19
# don't swap
# sex: 67
# age: f
# swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 78
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 48
# don't swap
# sex: f
# age: 60
# don't swap
# sex: m
# age: 15
# don't swap
# sex: f
# age: 34
# don't swap
# sex: m
# age: 79
# don't swap
# sex: m
# age: 42
# don't swap
# sex: m
# age: 32
# don't swap
# sex: m
# age: 12
# don't swap
# sex: 56
# age: f
# swap
# sex: m
# age: 61
# don't swap
# sex: 59
# age: m
# swap
# sex: f
# age: 36
# don't swap
# sex: 50
# age: f
# swap
# sex: m
# age: 81
# don't swap
# sex: m
# age: 62
# don't swap
# sex: m
# age: 56
# don't swap
# sex: m
# age: 83
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 52
# don't swap
# sex: 32
# age: f
# swap
# sex: 48
# age: m
# swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 3.48
# don't swap
# sex: m
# age: 56
# don't swap
# sex: f
# age: 54
# don't swap
# sex: f
# age: 41
# don't swap
# sex: m
# age: 71
# don't swap
# sex: m
# age: 53
# don't swap
# sex: f
# age: 45
# don't swap
# sex: m
# age: 36
# don't swap
# sex: m
# age: 69
# don't swap
# sex: f
# age: 9
# don't swap
# sex: m
# age: 20
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 45
# don't swap
# sex: 82
# age: m
# swap
# sex: 47
# age: m
# swap
# sex: f
# age: 72
# don't swap
# sex: f
# age: 41
# don't swap
# sex: m
# age: 39
# don't swap
# sex: f
# age: 62
# don't swap
# sex: m
# age: 26
# don't swap
# sex: m
# age: 54
# don't swap
# sex: m
# age: 50
# don't swap
# sex: m
# age: 59
# don't swap
# sex: m
# age: 33
# don't swap
# sex: f
# age: 38
# don't swap
# sex: m
# age: 67
# don't swap
# sex: m
# age: 57
# don't swap
# sex: f
# age: 22
# don't swap
# sex: m
# age: 62
# don't swap
# sex: f
# age: 35
# don't swap
# sex: m
# age: 67
# don't swap
# sex: f
# age: 84
# don't swap
# sex: f
# age: 85
# don't swap
# sex: m
# age: 47
# don't swap
# sex: m
# age: 31
# don't swap
# sex: m
# age: 23
# don't swap
# sex: f
# age: 3.8
# don't swap
# sex: 57
# age: m
# swap
# sex: m
# age: 47
# don't swap
# sex: f
# age: 25
# don't swap
# sex: f
# age: 23
# don't swap
# sex: m
# age: 77
# don't swap
# sex: f
# age: 55
# don't swap
# sex: m
# age: 60
# don't swap
# sex: m
# age: 53
# don't swap
# sex: m
# age: 51
# don't swap
# sex: f
# age: 12
# don't swap
# sex: f
# age: 74
# don't swap
# sex: m
# age: 67
# don't swap
# sex: m
# age: 54
# don't swap
# sex: f
# age: 9
# don't swap
# sex: m
# age: 51
# don't swap
# sex: m
# age: 24
# don't swap
# sex: f
# age: 66
# don't swap
# sex: f
# age: 21
# don't swap
# sex: f
# age: 28
# don't swap
# sex: f
# age: 26
# don't swap
# sex: m
# age: 80
# don't swap
# sex: f
# age: 3.32
# don't swap
# sex: m
# age: 19
# don't swap
# sex: m
# age: 44
# don't swap
# sex: f
# age: 82
# don't swap
# sex: f
# age: 53
# don't swap
# sex: f
# age: 60
# don't swap
# sex: f
# age: 59
# don't swap
# sex: m
# age: 34
# don't swap

# %%
stk[~stk["sex_corr"].isin(['f', 'm'])]
# Out:
# Empty DataFrame
# Columns: [id, sex and age, high_BP, heart_condition_detected_2017, married, job_status and living_area, average_blood_sugar, BMI, smoker_status, TreatmentA, TreatmentB, TreatmentC, TreatmentD, job_status_living_area, job_status, living_area, job_status_corr, living_area_corr, sex_and_age, sex, age, sex_corr, age_corr]
# Index: []
#
# [0 rows x 23 columns]

# %%
print(stk["sex_corr"].value_counts())
print(stk["age_corr"].unique())
# Out:
# f    5179
# m    3506
# Name: sex_corr, dtype: int64
# ['36' '40' '59' '33' '22' '60' '83' '47' '82' '49' '58' '4.88' '38' '50'
#  '84' '68' '52' '62' '35' '32' '14' '43' '12' '55' '30' '56' '78' '69'
#  '48' '64' '16' '63' '26' '29' '61' '79' '20' '5' '42' '72' '73' '21' '34'
#  '27' '41' '31' '18' '85' '3.72' '51' '4.08' '71' '76' '45' '67' '19' '17'
#  '46' '7' '65' '66' '81' '54' '39' '3.32' '6' '53' '28' '37' '57' '24' '8'
#  '80' '4' '13' '44' '4.72' '25' '3.88' '74' '77' '4.64' '15' '9' '4.24'
#  '23' '70' '11' '3.56' '75' '4.32' '3.48' '3.64' '4.4' '4.16' '10' '3.8'
#  '4.48' '3.08' '4.56' '3.16' '4.8' '3.24' '3.4']

# %% [markdown]
# We're not done yet. We need to convert these ages to floats. The remaining variables are to be cleaned as well, although I suspect that won't be as difficult as the first 2.

# %%
stk["age_corr"] = stk["age_corr"].apply(lambda x: int(float(x)))
print(stk["age_corr"].unique())
# Out:
# [36 40 59 33 22 60 83 47 82 49 58  4 38 50 84 68 52 62 35 32 14 43 12 55
#  30 56 78 69 48 64 16 63 26 29 61 79 20  5 42 72 73 21 34 27 41 31 18 85
#   3 51 71 76 45 67 19 17 46  7 65 66 81 54 39  6 53 28 37 57 24  8 80 13
#  44 25 74 77 15  9 23 70 11 75 10]

# %%
print(stk.shape)
stk.head()
# Out:
# (8685, 23)
#       id sex and age  high_BP  heart_condition_detected_2017  married  \
# 0  33327       F, 36      0.0                            0.0      1.0
# 1    839       F, 40      0.0                            0.0      1.0
# 2  11127       M, 59      0.0                            0.0      1.0
# 3  20768       33, F      0.0                            0.0      1.0
# 4  37774       F, 22      0.0                            0.0      0.0
#
#   job_status and living_area  average_blood_sugar   BMI  smoker_status  \
# 0      private_sector?Remote                76.05  33.4  active_smoker
# 1            City?government                73.77  30.1     non-smoker
# 2      business_owner?Remote                62.95  30.8            NaN
# 3        private_sector?City                68.81  36.5           quit
# 4        private_sector?City               122.89  30.8  active_smoker
#
#    TreatmentA  ...    job_status_living_area      job_status  living_area  \
# 0         NaN  ...  (private_sector, Remote)  private_sector       remote
# 1         NaN  ...        (City, government)            city   government
# 2         NaN  ...  (business_owner, Remote)  business_owner       remote
# 3         NaN  ...    (private_sector, City)  private_sector         city
# 4         NaN  ...    (private_sector, City)  private_sector         city
#
#   job_status_corr living_area_corr sex_and_age sex age sex_corr age_corr
# 0  private_sector           remote    (F,  36)   f  36        f       36
# 1      government             city    (F,  40)   f  40        f       40
# 2  business_owner           remote    (M,  59)   m  59        m       59
# 3  private_sector             city    (33,  F)  33   f        f       33
# 4  private_sector             city    (F,  22)   f  22        f       22
#
# [5 rows x 23 columns]

# %% [markdown]
# ### The remaining variables

# %% [markdown]
# <div class="alert alert-block alert-info">
# High_BP
# </div>

# %%
print(stk["high_BP"].unique())
print("---")
print(stk["high_BP"].value_counts())
print("---")
print("NaN values: {}".format(stk[stk["high_BP"].isnull()].shape[0]))

stk = stk[stk["high_BP"].isin(['0', '1'])]
print(stk.shape)
# Out:
# [ 0.  1. nan]
# ---
# 0.0    7871
# 1.0     808
# Name: high_BP, dtype: int64
# ---
# NaN values: 6
# (8679, 23)

# %% [markdown]
# <div class="alert alert-block alert-info">
# heart_condition_detected_2017
# </div>

# %%
print(stk["heart_condition_detected_2017"].unique())
print("---")
print(stk["heart_condition_detected_2017"].value_counts())
print("---")
print("NaN values: {}".format(stk[stk["heart_condition_detected_2017"].isnull()].shape[0]))

stk = stk[stk["heart_condition_detected_2017"].isin(['0', '1'])]
print(stk.shape)
# Out:
# [ 0.  1. nan]
# ---
# 0.0    8265
# 1.0     412
# Name: heart_condition_detected_2017, dtype: int64
# ---
# NaN values: 2
# (8677, 23)

# %%
print(stk["married"].unique())
print("---")
print(stk["married"].value_counts())
print("---")
print("NaN values: {}".format(stk[stk["married"].isnull()].shape[0]))

stk = stk[stk["married"].isin(['0', '1'])]
print(stk.shape)
# Out:
# [ 1.  0. nan]
# ---
# 1.0    5617
# 0.0    3059
# Name: married, dtype: int64
# ---
# NaN values: 1
# (8676, 23)

# %% [markdown]
# <div class="alert alert-block alert-info">
# smoker_status
# </div>

# %%
print(stk["smoker_status"].unique())
print(stk["smoker_status"].value_counts())
print("NaN values: {}".format(stk[stk["smoker_status"].isnull()].shape[0]))

smoker_status_keep = ["non-smoker", "quit", "active_smoker"]
stk = stk[stk["smoker_status"].isin(['non-smoker', 'quit', 'active_smoker'])]
stk.dropna(axis=0, how="all", subset=["smoker_status"], inplace=True)
print(stk.shape)
# Out:
# ['active_smoker' 'non-smoker' nan 'quit' '?' '>']
# non-smoker       3261
# quit             1476
# active_smoker    1246
# ?                   3
# >                   1
# Name: smoker_status, dtype: int64
# NaN values: 2689
# (5983, 23)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Approximately one-third of the column is null values. However, the imbalance of classes
# remain similar even after dropping these so I think it will be fine.
#
# I am assuming that being a smoker will have some correlation with stroke risk.
# </div>

# %%
print(stk["average_blood_sugar"].unique()[:5])
print(stk["average_blood_sugar"].value_counts().iloc[:5])
print("NaN values: {}".format(stk[stk["average_blood_sugar"].isnull()].shape[0]))

stk.dropna(axis=0, how="all", subset=["average_blood_sugar"], inplace=True)
# Out:
# [ 76.05  73.77  68.81 122.89 116.97]
# 77.13     7
# 106.82    6
# 69.29     6
# 84.77     6
# 85.98     6
# Name: average_blood_sugar, dtype: int64
# NaN values: 0

# %%
stk[stk["BMI"]=="."]
# Out:
#       id sex and age  high_BP  heart_condition_detected_2017  married  \
# 7563  83       F, 64      0.0                            0.0      1.0
#
#      job_status and living_area  average_blood_sugar BMI smoker_status  \
# 7563      business_owner?Remote               206.81   .    non-smoker
#
#       TreatmentA  ...    job_status_living_area      job_status  living_area  \
# 7563         NaN  ...  (business_owner, Remote)  business_owner       remote
#
#      job_status_corr living_area_corr sex_and_age sex age sex_corr age_corr
# 7563  business_owner           remote    (F,  64)   f  64        f       64
#
# [1 rows x 23 columns]

# %%
stk.loc[stk["BMI"]==".", "BMI"] = 24.0

# %%
print(stk["BMI"].unique()[:5])
print(stk["BMI"].value_counts().iloc[:5])
print("NaN values: {}".format(stk[stk["BMI"].isnull()].shape[0]))

stk.dropna(axis=0, how="all", subset=["BMI"], inplace=True)
# Out:
# ['33.4' '30.1' '36.5' '30.8' '30.7']
# 28.3    49
# 31.9    45
# 31.2    44
# 27.6    44
# 29.9    44
# Name: BMI, dtype: int64
# NaN values: 198

# %%
stk.shape
# Out:
# (5785, 23)

# %% [markdown]
# ## Finalising the training data set
#
# We consider the initial stages of data wrangling complete. Feature engineering continues in the next notebook, let's run the data through a few quick checks.

# %%
stk.columns
# Out:
# Index(['id', 'sex and age', 'high_BP', 'heart_condition_detected_2017',
#        'married', 'job_status and living_area', 'average_blood_sugar', 'BMI',
#        'smoker_status', 'TreatmentA', 'TreatmentB', 'TreatmentC', 'TreatmentD',
#        'job_status_living_area', 'job_status', 'living_area',
#        'job_status_corr', 'living_area_corr', 'sex_and_age', 'sex', 'age',
#        'sex_corr', 'age_corr'],
#       dtype='object')

# %%
columns_keep = ["id", "high_BP", "heart_condition_detected_2017",
                "married", "smoker_status", 
                "average_blood_sugar", "BMI",
                "job_status_corr", "living_area_corr", 
                "sex_corr", "age_corr",
            ]

stk_clean = stk[columns_keep]

# %%
stk_clean.smoker_status.isnull().value_counts()
# Out:
# False    5785
# Name: smoker_status, dtype: int64

# %%
stk_clean.dtypes
# Out:
# id                                 int64
# high_BP                          float64
# heart_condition_detected_2017    float64
# married                          float64
# smoker_status                     object
# average_blood_sugar              float64
# BMI                               object
# job_status_corr                   object
# living_area_corr                  object
# sex_corr                          object
# age_corr                           int64
# dtype: object

# %%
print(stk_clean.shape)
# Out:
# (5785, 11)

# %%
stk_clean.loc[:, "average_blood_sugar"] = stk_clean.loc[:, "average_blood_sugar"].apply(lambda x: float(x))
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
stk_clean.loc[:, "BMI"] = stk_clean.loc[:, "BMI"].apply(lambda x: float(x))

# %%
stk_clean["average_blood_sugar"].describe()
# Out:
# count    5785.000000
# mean      110.865570
# std        44.895935
# min        59.620000
# 25%        82.410000
# 50%        96.750000
# 75%       118.500000
# max       278.640000
# Name: average_blood_sugar, dtype: float64

# %%
stk_clean["BMI"].describe()
# Out:
# count    5785.000000
# mean       32.360847
# std         7.199487
# min        12.400000
# 25%        27.300000
# 50%        31.200000
# 75%        36.200000
# max        94.300000
# Name: BMI, dtype: float64

# %%
stk_clean.dtypes
# Out:
# id                                 int64
# high_BP                          float64
# heart_condition_detected_2017    float64
# married                          float64
# smoker_status                     object
# average_blood_sugar              float64
# BMI                              float64
# job_status_corr                   object
# living_area_corr                  object
# sex_corr                          object
# age_corr                           int64
# dtype: object

# %%
break
# Out:
#   File "<ipython-input-60-6aaf1f276005>", line 4
# SyntaxError: 'break' outside loop

# %%
stk_clean.to_csv("../data/test_processed.csv", index=False)

# %% [markdown]
# ### Quick Plots
#
# Quickly checking the distribution of the continuous variables

# %%
sns.distplot(stk_clean[stk_clean["stroke_in_2018"] == '1']["average_blood_sugar"], 
             kde = False, bins = 100, color = "black")
sns.distplot(stk_clean[stk_clean["stroke_in_2018"] == '0']["average_blood_sugar"], 
             kde = False, bins = 100, color = "purple")

# %%
sns.distplot(stk_clean[stk_clean["stroke_in_2018"] == '1']["BMI"], 
             kde = False, bins = 100, color = "black")
sns.distplot(stk_clean[stk_clean["stroke_in_2018"] == '0']["BMI"], 
             kde = False, bins = 100, color = "purple")
