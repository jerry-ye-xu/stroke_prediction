# %%
import pandas as pd

# %%
sample = pd.read_csv("../data/sample.csv")
sample
# Out:
#       id stroke_in_2018
# 0  33327              1
# 1    839              0
# 2  11127              0
# 3    ...            ...

# %%
sample.columns
# Out:
# Index(['id', 'stroke_in_2018'], dtype='object')

# %%
sample.dtypes
# Out:
# id                object
# stroke_in_2018    object
# dtype: object

# %%
df = pd.read_csv("../data/test.csv")
df
# Out:
#          id sex and age  high_BP  heart_condition_detected_2017  married  \
# 0     33327       F, 36      0.0                            0.0      1.0
# 1       839       F, 40      0.0                            0.0      1.0
# 2     11127       M, 59      0.0                            0.0      1.0
# 3     20768       33, F      0.0                            0.0      1.0
# 4     37774       F, 22      0.0                            0.0      0.0
# 5      4283       M, 60      0.0                            1.0      1.0
# 6     13832       F, 83      0.0                            0.0      1.0
# 7      4579       M, 47      0.0                            1.0      0.0
# 8     26781       F, 82      0.0                            0.0      1.0
# 9     17196       F, 49      0.0                            0.0      1.0
# 10     2514       M, 58      0.0                            0.0      1.0
# 11    19277       M, 82      1.0                            0.0      1.0
# ...

# %%
df["stroke_in_2018"] = '0'

# %%
df[["id", "stroke_in_2018"]].to_csv("../submission/test_submission.csv", index=False)

# %%
pd.read_csv("../submission/test_submission.csv")
# Out:
#          id  stroke_in_2018
# 0     33327               0
# 1       839               0
# 2     11127               0
# 3     20768               0
# 4     37774               0
# 5      4283               0
# 6     13832               0
# 7      4579               0
# 8     26781               0
# 9     17196               0
# 10     2514               0
# 11    19277               0
# 12    17398               0
# 13    31096               0
# 14    20650               0
# 15     3184               0
# 16    25947               0
# 17     5128               0
# 18    23326               0
# 19    30751               0
# 20     2813               0
# 21    15246               0
# 22     2554               0
# 23    11821               0
# 24    36075               0
# 25    22637               0
# 26    30739               0
# 27     5329               0
# 28    41161               0
# 29    30743               0
# ...     ...             ...
# 8688  14277               0
# ...
